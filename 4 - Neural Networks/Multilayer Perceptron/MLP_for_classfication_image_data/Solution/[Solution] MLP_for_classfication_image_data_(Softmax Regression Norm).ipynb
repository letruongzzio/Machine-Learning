# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# From (redirected): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP&confirm=t&uuid=a0c5ab86-86be-4fab-9a43-4e1be002030c
# To: /home/server-ailab-12gb/Khoa/AIO2023/hint/Final/sol/FER-2013.zip
# 100%|██████████████████████████████████████| 63.3M/63.3M [00:03<00:00, 16.6MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ##### Softmax Regression Norm

# %%
class SoftMaxRegression(nn.Module):
    def __init__(self, input_dims, num_classes):
        super(SoftMaxRegression, self).__init__()
        self.linear = nn.Linear(input_dims, num_classes)

    def forward(self, x):
        x = nn.Flatten()(x)
        out = self.linear(x)
        return out

model = SoftMaxRegression(input_dims=180*180, num_classes=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.9031,  Train_Acc: 0.2830, Val_Loss: 1.9890,  Val_Acc: 0.2537
# Epoch 2/100, Train_Loss: 1.8258,  Train_Acc: 0.3152, Val_Loss: 1.9477,  Val_Acc: 0.2896
# Epoch 3/100, Train_Loss: 1.7883,  Train_Acc: 0.3293, Val_Loss: 1.9911,  Val_Acc: 0.3009
# Epoch 4/100, Train_Loss: 1.7841,  Train_Acc: 0.3308, Val_Loss: 1.9879,  Val_Acc: 0.2930
# Epoch 5/100, Train_Loss: 1.7693,  Train_Acc: 0.3399, Val_Loss: 2.0800,  Val_Acc: 0.2800
# Epoch 6/100, Train_Loss: 1.7562,  Train_Acc: 0.3414, Val_Loss: 1.9830,  Val_Acc: 0.2597
# Epoch 7/100, Train_Loss: 1.7789,  Train_Acc: 0.3374, Val_Loss: 2.0651,  Val_Acc: 0.2651
# Epoch 8/100, Train_Loss: 1.7328,  Train_Acc: 0.3492, Val_Loss: 1.9066,  Val_Acc: 0.2942
# Epoch 9/100, Train_Loss: 1.7381,  Train_Acc: 0.3496, Val_Loss: 2.0355,  Val_Acc: 0.2662
# Epoch 10/100, Train_Loss: 1.7430,  Train_Acc: 0.3486, Val_Loss: 1.9155,  Val_Acc: 0.3172
# Epoch 11/100, Train_Loss: 1.7360,  Train_Acc: 0.3519, Val_Loss: 2.0639,  Val_Acc: 0.2817
# Epoch 12/100, Train_Loss: 1.7363,  Train_Acc: 0.3518, Val_Loss: 2.3635,  Val_Acc: 0.2857
# Epoch 13/100, Train_Loss: 1.7594,  Train_Acc: 0.3461, Val_Loss: 1.9693,  Val_Acc: 0.3058
# Epoch 14/100, Train_Loss: 1.7480,  Train_Acc: 0.3502, Val_Loss: 2.1202,  Val_Acc: 0.2742
# Epoch 15/100, Train_Loss: 1.7388,  Train_Acc: 0.3557, Val_Loss: 1.8554,  Val_Acc: 0.3381
# Epoch 16/100, Train_Loss: 1.7105,  Train_Acc: 0.3565, Val_Loss: 2.0121,  Val_Acc: 0.2749
# Epoch 17/100, Train_Loss: 1.7194,  Train_Acc: 0.3556, Val_Loss: 1.9673,  Val_Acc: 0.3058
# Epoch 18/100, Train_Loss: 1.7451,  Train_Acc: 0.3543, Val_Loss: 2.0734,  Val_Acc: 0.2951
# Epoch 19/100, Train_Loss: 1.7207,  Train_Acc: 0.3568, Val_Loss: 2.0105,  Val_Acc: 0.3064
# Epoch 20/100, Train_Loss: 1.7135,  Train_Acc: 0.3588, Val_Loss: 2.0298,  Val_Acc: 0.2835
# Epoch 21/100, Train_Loss: 1.7078,  Train_Acc: 0.3588, Val_Loss: 2.4535,  Val_Acc: 0.2566
# Epoch 22/100, Train_Loss: 1.7501,  Train_Acc: 0.3579, Val_Loss: 2.0226,  Val_Acc: 0.2736
# Epoch 23/100, Train_Loss: 1.7024,  Train_Acc: 0.3677, Val_Loss: 2.0181,  Val_Acc: 0.2863
# Epoch 24/100, Train_Loss: 1.7160,  Train_Acc: 0.3605, Val_Loss: 2.1462,  Val_Acc: 0.2619
# Epoch 25/100, Train_Loss: 1.7130,  Train_Acc: 0.3646, Val_Loss: 1.8755,  Val_Acc: 0.3104
# Epoch 26/100, Train_Loss: 1.7061,  Train_Acc: 0.3678, Val_Loss: 1.9605,  Val_Acc: 0.3013
# Epoch 27/100, Train_Loss: 1.7197,  Train_Acc: 0.3667, Val_Loss: 1.8632,  Val_Acc: 0.3352
# Epoch 28/100, Train_Loss: 1.6986,  Train_Acc: 0.3681, Val_Loss: 2.5290,  Val_Acc: 0.2825
# Epoch 29/100, Train_Loss: 1.7011,  Train_Acc: 0.3695, Val_Loss: 2.0662,  Val_Acc: 0.2673
# Epoch 30/100, Train_Loss: 1.6950,  Train_Acc: 0.3664, Val_Loss: 2.0125,  Val_Acc: 0.3031
# Epoch 31/100, Train_Loss: 1.6985,  Train_Acc: 0.3696, Val_Loss: 1.9725,  Val_Acc: 0.3164
# Epoch 32/100, Train_Loss: 1.7050,  Train_Acc: 0.3703, Val_Loss: 1.9201,  Val_Acc: 0.2958
# Epoch 33/100, Train_Loss: 1.6845,  Train_Acc: 0.3753, Val_Loss: 2.0875,  Val_Acc: 0.2891
# Epoch 34/100, Train_Loss: 1.6891,  Train_Acc: 0.3679, Val_Loss: 2.0400,  Val_Acc: 0.2941
# Epoch 35/100, Train_Loss: 1.7034,  Train_Acc: 0.3696, Val_Loss: 2.0767,  Val_Acc: 0.2871
# Epoch 36/100, Train_Loss: 1.6629,  Train_Acc: 0.3764, Val_Loss: 1.9640,  Val_Acc: 0.3037
# Epoch 37/100, Train_Loss: 1.6837,  Train_Acc: 0.3756, Val_Loss: 1.9376,  Val_Acc: 0.2916
# Epoch 38/100, Train_Loss: 1.6691,  Train_Acc: 0.3733, Val_Loss: 1.8517,  Val_Acc: 0.3130
# Epoch 39/100, Train_Loss: 1.6843,  Train_Acc: 0.3739, Val_Loss: 2.2871,  Val_Acc: 0.2991
# Epoch 40/100, Train_Loss: 1.6668,  Train_Acc: 0.3757, Val_Loss: 1.8933,  Val_Acc: 0.3160
# Epoch 41/100, Train_Loss: 1.6750,  Train_Acc: 0.3769, Val_Loss: 2.0490,  Val_Acc: 0.2966
# Epoch 42/100, Train_Loss: 1.6657,  Train_Acc: 0.3789, Val_Loss: 2.0788,  Val_Acc: 0.3029
# Epoch 43/100, Train_Loss: 1.6868,  Train_Acc: 0.3758, Val_Loss: 1.9211,  Val_Acc: 0.3146
# Epoch 44/100, Train_Loss: 1.6822,  Train_Acc: 0.3748, Val_Loss: 2.0242,  Val_Acc: 0.2770
# Epoch 45/100, Train_Loss: 1.6896,  Train_Acc: 0.3740, Val_Loss: 2.2039,  Val_Acc: 0.2796
# Epoch 46/100, Train_Loss: 1.6968,  Train_Acc: 0.3736, Val_Loss: 1.9490,  Val_Acc: 0.2806
# Epoch 47/100, Train_Loss: 1.6539,  Train_Acc: 0.3807, Val_Loss: 2.1208,  Val_Acc: 0.3151
# Epoch 48/100, Train_Loss: 1.6921,  Train_Acc: 0.3733, Val_Loss: 2.0564,  Val_Acc: 0.2862
# Epoch 49/100, Train_Loss: 1.7069,  Train_Acc: 0.3726, Val_Loss: 2.0843,  Val_Acc: 0.2917
# Epoch 50/100, Train_Loss: 1.6816,  Train_Acc: 0.3741, Val_Loss: 2.2593,  Val_Acc: 0.2984
# Epoch 51/100, Train_Loss: 1.6821,  Train_Acc: 0.3780, Val_Loss: 2.0651,  Val_Acc: 0.3094
# Epoch 52/100, Train_Loss: 1.6635,  Train_Acc: 0.3812, Val_Loss: 2.3902,  Val_Acc: 0.2749
# Epoch 53/100, Train_Loss: 1.6858,  Train_Acc: 0.3770, Val_Loss: 1.8176,  Val_Acc: 0.3231
# Epoch 54/100, Train_Loss: 1.6839,  Train_Acc: 0.3768, Val_Loss: 2.1558,  Val_Acc: 0.2824
# Epoch 55/100, Train_Loss: 1.6752,  Train_Acc: 0.3805, Val_Loss: 1.8646,  Val_Acc: 0.3033
# Epoch 56/100, Train_Loss: 1.6570,  Train_Acc: 0.3807, Val_Loss: 2.1783,  Val_Acc: 0.3082
# Epoch 57/100, Train_Loss: 1.6842,  Train_Acc: 0.3762, Val_Loss: 2.7802,  Val_Acc: 0.2419
# Epoch 58/100, Train_Loss: 1.6719,  Train_Acc: 0.3758, Val_Loss: 1.9742,  Val_Acc: 0.2806
# Epoch 59/100, Train_Loss: 1.6489,  Train_Acc: 0.3836, Val_Loss: 2.3625,  Val_Acc: 0.2870
# Epoch 60/100, Train_Loss: 1.6651,  Train_Acc: 0.3833, Val_Loss: 2.1229,  Val_Acc: 0.2866
# Epoch 61/100, Train_Loss: 1.6396,  Train_Acc: 0.3879, Val_Loss: 2.4851,  Val_Acc: 0.2485
# Epoch 62/100, Train_Loss: 1.6544,  Train_Acc: 0.3863, Val_Loss: 2.0137,  Val_Acc: 0.2973
# Epoch 63/100, Train_Loss: 1.6644,  Train_Acc: 0.3836, Val_Loss: 1.8729,  Val_Acc: 0.3193
# Epoch 64/100, Train_Loss: 1.6619,  Train_Acc: 0.3856, Val_Loss: 1.8507,  Val_Acc: 0.3286
# Epoch 65/100, Train_Loss: 1.6292,  Train_Acc: 0.3892, Val_Loss: 2.0331,  Val_Acc: 0.3043
# Epoch 66/100, Train_Loss: 1.6637,  Train_Acc: 0.3806, Val_Loss: 2.0953,  Val_Acc: 0.3082
# Epoch 67/100, Train_Loss: 1.6632,  Train_Acc: 0.3825, Val_Loss: 2.8836,  Val_Acc: 0.2460
# Epoch 68/100, Train_Loss: 1.6819,  Train_Acc: 0.3831, Val_Loss: 1.8638,  Val_Acc: 0.3083
# Epoch 69/100, Train_Loss: 1.6376,  Train_Acc: 0.3898, Val_Loss: 1.9298,  Val_Acc: 0.3125
# Epoch 70/100, Train_Loss: 1.6527,  Train_Acc: 0.3840, Val_Loss: 1.8924,  Val_Acc: 0.3142
# Epoch 71/100, Train_Loss: 1.6498,  Train_Acc: 0.3877, Val_Loss: 2.1040,  Val_Acc: 0.3149
# Epoch 72/100, Train_Loss: 1.6805,  Train_Acc: 0.3840, Val_Loss: 2.1121,  Val_Acc: 0.2646
# Epoch 73/100, Train_Loss: 1.6813,  Train_Acc: 0.3788, Val_Loss: 2.5213,  Val_Acc: 0.2625
# Epoch 74/100, Train_Loss: 1.6470,  Train_Acc: 0.3869, Val_Loss: 2.0325,  Val_Acc: 0.2814
# Epoch 75/100, Train_Loss: 1.6491,  Train_Acc: 0.3903, Val_Loss: 1.9564,  Val_Acc: 0.3266
# Epoch 76/100, Train_Loss: 1.6477,  Train_Acc: 0.3874, Val_Loss: 1.9450,  Val_Acc: 0.3296
# Epoch 77/100, Train_Loss: 1.6469,  Train_Acc: 0.3866, Val_Loss: 1.9277,  Val_Acc: 0.2874
# Epoch 78/100, Train_Loss: 1.6284,  Train_Acc: 0.3919, Val_Loss: 1.9976,  Val_Acc: 0.3317
# Epoch 79/100, Train_Loss: 1.6542,  Train_Acc: 0.3861, Val_Loss: 1.9277,  Val_Acc: 0.3186
# Epoch 80/100, Train_Loss: 1.6649,  Train_Acc: 0.3811, Val_Loss: 2.5348,  Val_Acc: 0.2790
# Epoch 81/100, Train_Loss: 1.6538,  Train_Acc: 0.3898, Val_Loss: 2.0032,  Val_Acc: 0.2887
# Epoch 82/100, Train_Loss: 1.6582,  Train_Acc: 0.3884, Val_Loss: 2.1368,  Val_Acc: 0.3002
# Epoch 83/100, Train_Loss: 1.6487,  Train_Acc: 0.3894, Val_Loss: 2.5240,  Val_Acc: 0.2738
# Epoch 84/100, Train_Loss: 1.6510,  Train_Acc: 0.3901, Val_Loss: 1.8559,  Val_Acc: 0.3256
# Epoch 85/100, Train_Loss: 1.6434,  Train_Acc: 0.3884, Val_Loss: 2.2522,  Val_Acc: 0.2834
# Epoch 86/100, Train_Loss: 1.6389,  Train_Acc: 0.3902, Val_Loss: 2.1958,  Val_Acc: 0.2870
# Epoch 87/100, Train_Loss: 1.6395,  Train_Acc: 0.3889, Val_Loss: 2.0511,  Val_Acc: 0.2938
# Epoch 88/100, Train_Loss: 1.6599,  Train_Acc: 0.3850, Val_Loss: 1.8894,  Val_Acc: 0.3224
# Epoch 89/100, Train_Loss: 1.5992,  Train_Acc: 0.3973, Val_Loss: 1.8670,  Val_Acc: 0.3316
# Epoch 90/100, Train_Loss: 1.6257,  Train_Acc: 0.3950, Val_Loss: 2.1741,  Val_Acc: 0.2860
# Epoch 91/100, Train_Loss: 1.6554,  Train_Acc: 0.3895, Val_Loss: 2.2060,  Val_Acc: 0.2981
# Epoch 92/100, Train_Loss: 1.6647,  Train_Acc: 0.3869, Val_Loss: 2.2841,  Val_Acc: 0.2955
# Epoch 93/100, Train_Loss: 1.6548,  Train_Acc: 0.3849, Val_Loss: 1.9445,  Val_Acc: 0.2984
# Epoch 94/100, Train_Loss: 1.6514,  Train_Acc: 0.3852, Val_Loss: 2.8919,  Val_Acc: 0.2555
# Epoch 95/100, Train_Loss: 1.6346,  Train_Acc: 0.3970, Val_Loss: 1.9331,  Val_Acc: 0.2958
# Epoch 96/100, Train_Loss: 1.6397,  Train_Acc: 0.3932, Val_Loss: 1.8323,  Val_Acc: 0.3300
# Epoch 97/100, Train_Loss: 1.6320,  Train_Acc: 0.3908, Val_Loss: 2.2178,  Val_Acc: 0.3013
# Epoch 98/100, Train_Loss: 1.6350,  Train_Acc: 0.3900, Val_Loss: 1.8873,  Val_Acc: 0.3227
# Epoch 99/100, Train_Loss: 1.6635,  Train_Acc: 0.3863, Val_Loss: 1.9323,  Val_Acc: 0.2944
# Epoch 100/100, Train_Loss: 1.6415,  Train_Acc: 0.3903, Val_Loss: 2.3312,  Val_Acc: 0.2866

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
