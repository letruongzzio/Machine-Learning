# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = tf.reshape(x_train, (-1, 28*28))
x_test  = tf.reshape(x_test, (-1, 28*28))

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# data normalization

mean = np.mean(x_train)
std  = np.std(x_train)

x_train = (x_train-mean)/std
x_test  = (x_test-mean)/std

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
inputs = keras.Input(shape=(784,))
x = keras.layers.Dense(256, activation='relu')(inputs)
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dense(256, activation='relu')(x)
output = keras.layers.Dense(10, activation='softmax')(x)
model = keras.Model(inputs, output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 335,114
# Trainable params: 335,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 1s - loss: 0.8082 - sparse_categorical_accuracy: 0.7258 - val_loss: 0.6149 - val_sparse_categorical_accuracy: 0.7869 - 1s/epoch - 6ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.5518 - sparse_categorical_accuracy: 0.8076 - val_loss: 0.5423 - val_sparse_categorical_accuracy: 0.8053 - 1s/epoch - 5ms/step
# Epoch 3/100
# 235/235 - 1s - loss: 0.4992 - sparse_categorical_accuracy: 0.8251 - val_loss: 0.5099 - val_sparse_categorical_accuracy: 0.8182 - 1s/epoch - 5ms/step
# Epoch 4/100
# 235/235 - 1s - loss: 0.4693 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.4881 - val_sparse_categorical_accuracy: 0.8261 - 1s/epoch - 5ms/step
# Epoch 5/100
# 235/235 - 1s - loss: 0.4496 - sparse_categorical_accuracy: 0.8424 - val_loss: 0.4724 - val_sparse_categorical_accuracy: 0.8309 - 1s/epoch - 5ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.4341 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.4604 - val_sparse_categorical_accuracy: 0.8354 - 1s/epoch - 5ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.4221 - sparse_categorical_accuracy: 0.8521 - val_loss: 0.4538 - val_sparse_categorical_accuracy: 0.8382 - 1s/epoch - 5ms/step
# Epoch 8/100
# 235/235 - 1s - loss: 0.4118 - sparse_categorical_accuracy: 0.8568 - val_loss: 0.4435 - val_sparse_categorical_accuracy: 0.8405 - 1s/epoch - 5ms/step
# Epoch 9/100
# 235/235 - 1s - loss: 0.4029 - sparse_categorical_accuracy: 0.8599 - val_loss: 0.4353 - val_sparse_categorical_accuracy: 0.8447 - 1s/epoch - 5ms/step
# Epoch 10/100
# 235/235 - 1s - loss: 0.3950 - sparse_categorical_accuracy: 0.8626 - val_loss: 0.4314 - val_sparse_categorical_accuracy: 0.8449 - 1s/epoch - 5ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.3880 - sparse_categorical_accuracy: 0.8648 - val_loss: 0.4277 - val_sparse_categorical_accuracy: 0.8461 - 1s/epoch - 5ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.3821 - sparse_categorical_accuracy: 0.8674 - val_loss: 0.4190 - val_sparse_categorical_accuracy: 0.8508 - 1s/epoch - 5ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.3762 - sparse_categorical_accuracy: 0.8681 - val_loss: 0.4175 - val_sparse_categorical_accuracy: 0.8495 - 1s/epoch - 5ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.3711 - sparse_categorical_accuracy: 0.8706 - val_loss: 0.4163 - val_sparse_categorical_accuracy: 0.8502 - 1s/epoch - 5ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.3659 - sparse_categorical_accuracy: 0.8727 - val_loss: 0.4123 - val_sparse_categorical_accuracy: 0.8521 - 1s/epoch - 4ms/step
# Epoch 16/100
# 235/235 - 1s - loss: 0.3614 - sparse_categorical_accuracy: 0.8733 - val_loss: 0.4057 - val_sparse_categorical_accuracy: 0.8579 - 1s/epoch - 5ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.3568 - sparse_categorical_accuracy: 0.8748 - val_loss: 0.4109 - val_sparse_categorical_accuracy: 0.8492 - 1s/epoch - 5ms/step
# Epoch 18/100
# 235/235 - 1s - loss: 0.3529 - sparse_categorical_accuracy: 0.8770 - val_loss: 0.4010 - val_sparse_categorical_accuracy: 0.8569 - 1s/epoch - 5ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.3490 - sparse_categorical_accuracy: 0.8777 - val_loss: 0.4020 - val_sparse_categorical_accuracy: 0.8559 - 1s/epoch - 5ms/step
# Epoch 20/100
# 235/235 - 1s - loss: 0.3457 - sparse_categorical_accuracy: 0.8789 - val_loss: 0.3939 - val_sparse_categorical_accuracy: 0.8596 - 1s/epoch - 5ms/step
# Epoch 21/100
# 235/235 - 1s - loss: 0.3421 - sparse_categorical_accuracy: 0.8798 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8608 - 1s/epoch - 5ms/step
# Epoch 22/100
# 235/235 - 1s - loss: 0.3389 - sparse_categorical_accuracy: 0.8810 - val_loss: 0.3898 - val_sparse_categorical_accuracy: 0.8620 - 1s/epoch - 5ms/step
# Epoch 23/100
# 235/235 - 1s - loss: 0.3355 - sparse_categorical_accuracy: 0.8825 - val_loss: 0.3887 - val_sparse_categorical_accuracy: 0.8623 - 1s/epoch - 5ms/step
# Epoch 24/100
# 235/235 - 1s - loss: 0.3327 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.3887 - val_sparse_categorical_accuracy: 0.8604 - 1s/epoch - 5ms/step
# Epoch 25/100
# 235/235 - 1s - loss: 0.3297 - sparse_categorical_accuracy: 0.8843 - val_loss: 0.3818 - val_sparse_categorical_accuracy: 0.8638 - 1s/epoch - 5ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.3271 - sparse_categorical_accuracy: 0.8842 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8643 - 1s/epoch - 5ms/step
# Epoch 27/100
# 235/235 - 1s - loss: 0.3244 - sparse_categorical_accuracy: 0.8853 - val_loss: 0.3809 - val_sparse_categorical_accuracy: 0.8632 - 1s/epoch - 5ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.3214 - sparse_categorical_accuracy: 0.8862 - val_loss: 0.3785 - val_sparse_categorical_accuracy: 0.8636 - 1s/epoch - 5ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.3191 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3801 - val_sparse_categorical_accuracy: 0.8631 - 1s/epoch - 5ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.3165 - sparse_categorical_accuracy: 0.8887 - val_loss: 0.3737 - val_sparse_categorical_accuracy: 0.8665 - 1s/epoch - 5ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.3145 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.3753 - val_sparse_categorical_accuracy: 0.8647 - 1s/epoch - 5ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.3117 - sparse_categorical_accuracy: 0.8902 - val_loss: 0.3739 - val_sparse_categorical_accuracy: 0.8651 - 1s/epoch - 4ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.3094 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.3713 - val_sparse_categorical_accuracy: 0.8669 - 1s/epoch - 5ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.3074 - sparse_categorical_accuracy: 0.8912 - val_loss: 0.3682 - val_sparse_categorical_accuracy: 0.8693 - 1s/epoch - 5ms/step
# Epoch 35/100
# 235/235 - 1s - loss: 0.3055 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.3671 - val_sparse_categorical_accuracy: 0.8672 - 1s/epoch - 5ms/step
# Epoch 36/100
# 235/235 - 1s - loss: 0.3034 - sparse_categorical_accuracy: 0.8928 - val_loss: 0.3656 - val_sparse_categorical_accuracy: 0.8683 - 1s/epoch - 5ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.3010 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3699 - val_sparse_categorical_accuracy: 0.8655 - 1s/epoch - 5ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.2995 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3646 - val_sparse_categorical_accuracy: 0.8691 - 1s/epoch - 4ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.2975 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.3626 - val_sparse_categorical_accuracy: 0.8687 - 1s/epoch - 5ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.2954 - sparse_categorical_accuracy: 0.8957 - val_loss: 0.3624 - val_sparse_categorical_accuracy: 0.8703 - 1s/epoch - 5ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.2936 - sparse_categorical_accuracy: 0.8961 - val_loss: 0.3614 - val_sparse_categorical_accuracy: 0.8693 - 1s/epoch - 5ms/step
# Epoch 42/100
# 235/235 - 1s - loss: 0.2920 - sparse_categorical_accuracy: 0.8976 - val_loss: 0.3617 - val_sparse_categorical_accuracy: 0.8690 - 1s/epoch - 5ms/step
# Epoch 43/100
# 235/235 - 1s - loss: 0.2901 - sparse_categorical_accuracy: 0.8973 - val_loss: 0.3600 - val_sparse_categorical_accuracy: 0.8698 - 1s/epoch - 5ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.2885 - sparse_categorical_accuracy: 0.8978 - val_loss: 0.3598 - val_sparse_categorical_accuracy: 0.8708 - 1s/epoch - 5ms/step
# Epoch 45/100
# 235/235 - 1s - loss: 0.2868 - sparse_categorical_accuracy: 0.8989 - val_loss: 0.3578 - val_sparse_categorical_accuracy: 0.8718 - 1s/epoch - 5ms/step
# Epoch 46/100
# 235/235 - 1s - loss: 0.2852 - sparse_categorical_accuracy: 0.8990 - val_loss: 0.3570 - val_sparse_categorical_accuracy: 0.8737 - 1s/epoch - 5ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.2834 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.3559 - val_sparse_categorical_accuracy: 0.8708 - 1s/epoch - 5ms/step
# Epoch 48/100
# 235/235 - 1s - loss: 0.2819 - sparse_categorical_accuracy: 0.9008 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.8727 - 1s/epoch - 5ms/step
# Epoch 49/100
# 235/235 - 1s - loss: 0.2800 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.3547 - val_sparse_categorical_accuracy: 0.8716 - 1s/epoch - 5ms/step
# Epoch 50/100
# 235/235 - 1s - loss: 0.2786 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.3523 - val_sparse_categorical_accuracy: 0.8776 - 1s/epoch - 5ms/step
# Epoch 51/100
# 235/235 - 1s - loss: 0.2770 - sparse_categorical_accuracy: 0.9024 - val_loss: 0.3497 - val_sparse_categorical_accuracy: 0.8758 - 1s/epoch - 5ms/step
# Epoch 52/100
# 235/235 - 1s - loss: 0.2757 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.8750 - 1s/epoch - 5ms/step
# Epoch 53/100
# 235/235 - 1s - loss: 0.2740 - sparse_categorical_accuracy: 0.9033 - val_loss: 0.3521 - val_sparse_categorical_accuracy: 0.8733 - 1s/epoch - 5ms/step
# Epoch 54/100
# 235/235 - 1s - loss: 0.2727 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.3539 - val_sparse_categorical_accuracy: 0.8733 - 1s/epoch - 5ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.2713 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8777 - 1s/epoch - 5ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.2698 - sparse_categorical_accuracy: 0.9052 - val_loss: 0.3512 - val_sparse_categorical_accuracy: 0.8742 - 1s/epoch - 5ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.2684 - sparse_categorical_accuracy: 0.9058 - val_loss: 0.3482 - val_sparse_categorical_accuracy: 0.8769 - 1s/epoch - 5ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.2670 - sparse_categorical_accuracy: 0.9061 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8752 - 1s/epoch - 5ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.2657 - sparse_categorical_accuracy: 0.9067 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8737 - 1s/epoch - 5ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.2643 - sparse_categorical_accuracy: 0.9073 - val_loss: 0.3474 - val_sparse_categorical_accuracy: 0.8769 - 1s/epoch - 5ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.2631 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.3429 - val_sparse_categorical_accuracy: 0.8780 - 1s/epoch - 5ms/step
# Epoch 62/100
# 235/235 - 1s - loss: 0.2615 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.3465 - val_sparse_categorical_accuracy: 0.8745 - 1s/epoch - 5ms/step
# Epoch 63/100
# 235/235 - 1s - loss: 0.2603 - sparse_categorical_accuracy: 0.9082 - val_loss: 0.3424 - val_sparse_categorical_accuracy: 0.8781 - 1s/epoch - 5ms/step
# Epoch 64/100
# 235/235 - 1s - loss: 0.2589 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.3426 - val_sparse_categorical_accuracy: 0.8770 - 1s/epoch - 5ms/step
# Epoch 65/100
# 235/235 - 1s - loss: 0.2576 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.3465 - val_sparse_categorical_accuracy: 0.8761 - 1s/epoch - 5ms/step
# Epoch 66/100
# 235/235 - 1s - loss: 0.2564 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8754 - 1s/epoch - 5ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.2550 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.3390 - val_sparse_categorical_accuracy: 0.8785 - 1s/epoch - 5ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.2538 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8760 - 1s/epoch - 5ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.2527 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.3397 - val_sparse_categorical_accuracy: 0.8783 - 1s/epoch - 5ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.2515 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.3402 - val_sparse_categorical_accuracy: 0.8765 - 1s/epoch - 5ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.2502 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8783 - 1s/epoch - 5ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.2492 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.3417 - val_sparse_categorical_accuracy: 0.8772 - 1s/epoch - 5ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.2479 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.3359 - val_sparse_categorical_accuracy: 0.8807 - 1s/epoch - 5ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.2469 - sparse_categorical_accuracy: 0.9137 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.2455 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.3365 - val_sparse_categorical_accuracy: 0.8798 - 1s/epoch - 5ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.2446 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.3393 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 77/100
# 235/235 - 1s - loss: 0.2436 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.8801 - 1s/epoch - 5ms/step
# Epoch 78/100
# 235/235 - 1s - loss: 0.2422 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.3408 - val_sparse_categorical_accuracy: 0.8784 - 1s/epoch - 5ms/step
# Epoch 79/100
# 235/235 - 1s - loss: 0.2412 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 80/100
# 235/235 - 1s - loss: 0.2401 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.3368 - val_sparse_categorical_accuracy: 0.8792 - 1s/epoch - 5ms/step
# Epoch 81/100
# 235/235 - 1s - loss: 0.2389 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.3376 - val_sparse_categorical_accuracy: 0.8774 - 1s/epoch - 5ms/step
# Epoch 82/100
# 235/235 - 1s - loss: 0.2380 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.3335 - val_sparse_categorical_accuracy: 0.8804 - 1s/epoch - 5ms/step
# Epoch 83/100
# 235/235 - 1s - loss: 0.2370 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.3338 - val_sparse_categorical_accuracy: 0.8811 - 1s/epoch - 5ms/step
# Epoch 84/100
# 235/235 - 1s - loss: 0.2359 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.3353 - val_sparse_categorical_accuracy: 0.8807 - 1s/epoch - 5ms/step
# Epoch 85/100
# 235/235 - 1s - loss: 0.2348 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.3330 - val_sparse_categorical_accuracy: 0.8810 - 1s/epoch - 5ms/step
# Epoch 86/100
# 235/235 - 1s - loss: 0.2337 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 87/100
# 235/235 - 1s - loss: 0.2328 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.3314 - val_sparse_categorical_accuracy: 0.8827 - 1s/epoch - 5ms/step
# Epoch 88/100
# 235/235 - 1s - loss: 0.2315 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.3316 - val_sparse_categorical_accuracy: 0.8816 - 1s/epoch - 5ms/step
# Epoch 89/100
# 235/235 - 1s - loss: 0.2306 - sparse_categorical_accuracy: 0.9183 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8800 - 1s/epoch - 5ms/step
# Epoch 90/100
# 235/235 - 1s - loss: 0.2292 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.8785 - 1s/epoch - 5ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.2287 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.3353 - val_sparse_categorical_accuracy: 0.8790 - 1s/epoch - 5ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.2275 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.3465 - val_sparse_categorical_accuracy: 0.8745 - 1s/epoch - 5ms/step
# Epoch 93/100
# 235/235 - 1s - loss: 0.2267 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.8815 - 1s/epoch - 5ms/step
# Epoch 94/100
# 235/235 - 1s - loss: 0.2255 - sparse_categorical_accuracy: 0.9216 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.8831 - 1s/epoch - 5ms/step
# Epoch 95/100
# 235/235 - 1s - loss: 0.2248 - sparse_categorical_accuracy: 0.9210 - val_loss: 0.3300 - val_sparse_categorical_accuracy: 0.8820 - 1s/epoch - 5ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.2237 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.3333 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 97/100
# 235/235 - 1s - loss: 0.2230 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8797 - 1s/epoch - 5ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.2217 - sparse_categorical_accuracy: 0.9228 - val_loss: 0.3352 - val_sparse_categorical_accuracy: 0.8795 - 1s/epoch - 5ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.2210 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.3290 - val_sparse_categorical_accuracy: 0.8815 - 1s/epoch - 5ms/step
# Epoch 100/100
# 235/235 - 1s - loss: 0.2197 - sparse_categorical_accuracy: 0.9233 - val_loss: 0.3276 - val_sparse_categorical_accuracy: 0.8843 - 1s/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
