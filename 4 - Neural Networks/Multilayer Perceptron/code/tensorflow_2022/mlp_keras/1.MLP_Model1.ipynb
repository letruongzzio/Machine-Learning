# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = tf.reshape(x_train, (-1, 28*28))
x_test  = tf.reshape(x_test, (-1, 28*28))

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# data normalization
mean = np.mean(x_train)
std  = np.std(x_train)

x_train = (x_train-mean)/std
x_test  = (x_test-mean)/std

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 1s - loss: 0.8047 - sparse_categorical_accuracy: 0.7271 - val_loss: 0.6177 - val_sparse_categorical_accuracy: 0.7841 - 1s/epoch - 6ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.5476 - sparse_categorical_accuracy: 0.8105 - val_loss: 0.5472 - val_sparse_categorical_accuracy: 0.8081 - 1s/epoch - 5ms/step
# Epoch 3/100
# 235/235 - 1s - loss: 0.4924 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.5082 - val_sparse_categorical_accuracy: 0.8210 - 1s/epoch - 5ms/step
# Epoch 4/100
# 235/235 - 1s - loss: 0.4622 - sparse_categorical_accuracy: 0.8406 - val_loss: 0.4863 - val_sparse_categorical_accuracy: 0.8285 - 1s/epoch - 4ms/step
# Epoch 5/100
# 235/235 - 1s - loss: 0.4416 - sparse_categorical_accuracy: 0.8473 - val_loss: 0.4714 - val_sparse_categorical_accuracy: 0.8332 - 1s/epoch - 5ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.4264 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.4606 - val_sparse_categorical_accuracy: 0.8360 - 1s/epoch - 5ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.4146 - sparse_categorical_accuracy: 0.8557 - val_loss: 0.4510 - val_sparse_categorical_accuracy: 0.8392 - 1s/epoch - 5ms/step
# Epoch 8/100
# 235/235 - 1s - loss: 0.4048 - sparse_categorical_accuracy: 0.8588 - val_loss: 0.4410 - val_sparse_categorical_accuracy: 0.8433 - 1s/epoch - 5ms/step
# Epoch 9/100
# 235/235 - 1s - loss: 0.3965 - sparse_categorical_accuracy: 0.8625 - val_loss: 0.4381 - val_sparse_categorical_accuracy: 0.8443 - 1s/epoch - 5ms/step
# Epoch 10/100
# 235/235 - 1s - loss: 0.3890 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.4299 - val_sparse_categorical_accuracy: 0.8491 - 1s/epoch - 5ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.3824 - sparse_categorical_accuracy: 0.8662 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.8499 - 1s/epoch - 5ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.3770 - sparse_categorical_accuracy: 0.8680 - val_loss: 0.4187 - val_sparse_categorical_accuracy: 0.8504 - 1s/epoch - 5ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.3715 - sparse_categorical_accuracy: 0.8698 - val_loss: 0.4149 - val_sparse_categorical_accuracy: 0.8522 - 1s/epoch - 5ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.3666 - sparse_categorical_accuracy: 0.8711 - val_loss: 0.4128 - val_sparse_categorical_accuracy: 0.8522 - 1s/epoch - 5ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.3622 - sparse_categorical_accuracy: 0.8723 - val_loss: 0.4105 - val_sparse_categorical_accuracy: 0.8539 - 1s/epoch - 5ms/step
# Epoch 16/100
# 235/235 - 1s - loss: 0.3578 - sparse_categorical_accuracy: 0.8740 - val_loss: 0.4077 - val_sparse_categorical_accuracy: 0.8559 - 1s/epoch - 5ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.3540 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.4033 - val_sparse_categorical_accuracy: 0.8547 - 1s/epoch - 4ms/step
# Epoch 18/100
# 235/235 - 1s - loss: 0.3504 - sparse_categorical_accuracy: 0.8775 - val_loss: 0.4001 - val_sparse_categorical_accuracy: 0.8571 - 1s/epoch - 5ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.3468 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.4002 - val_sparse_categorical_accuracy: 0.8584 - 1s/epoch - 5ms/step
# Epoch 20/100
# 235/235 - 1s - loss: 0.3436 - sparse_categorical_accuracy: 0.8784 - val_loss: 0.3937 - val_sparse_categorical_accuracy: 0.8586 - 1s/epoch - 5ms/step
# Epoch 21/100
# 235/235 - 1s - loss: 0.3399 - sparse_categorical_accuracy: 0.8805 - val_loss: 0.3973 - val_sparse_categorical_accuracy: 0.8573 - 1s/epoch - 5ms/step
# Epoch 22/100
# 235/235 - 1s - loss: 0.3370 - sparse_categorical_accuracy: 0.8810 - val_loss: 0.3900 - val_sparse_categorical_accuracy: 0.8622 - 1s/epoch - 4ms/step
# Epoch 23/100
# 235/235 - 1s - loss: 0.3340 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3906 - val_sparse_categorical_accuracy: 0.8607 - 1s/epoch - 5ms/step
# Epoch 24/100
# 235/235 - 1s - loss: 0.3312 - sparse_categorical_accuracy: 0.8833 - val_loss: 0.3900 - val_sparse_categorical_accuracy: 0.8609 - 1s/epoch - 5ms/step
# Epoch 25/100
# 235/235 - 1s - loss: 0.3289 - sparse_categorical_accuracy: 0.8842 - val_loss: 0.3846 - val_sparse_categorical_accuracy: 0.8650 - 1s/epoch - 5ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.3256 - sparse_categorical_accuracy: 0.8853 - val_loss: 0.3829 - val_sparse_categorical_accuracy: 0.8633 - 1s/epoch - 5ms/step
# Epoch 27/100
# 235/235 - 1s - loss: 0.3236 - sparse_categorical_accuracy: 0.8858 - val_loss: 0.3842 - val_sparse_categorical_accuracy: 0.8651 - 1s/epoch - 5ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.3206 - sparse_categorical_accuracy: 0.8874 - val_loss: 0.3798 - val_sparse_categorical_accuracy: 0.8658 - 1s/epoch - 5ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.3185 - sparse_categorical_accuracy: 0.8882 - val_loss: 0.3788 - val_sparse_categorical_accuracy: 0.8654 - 1s/epoch - 5ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.3158 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.3792 - val_sparse_categorical_accuracy: 0.8651 - 1s/epoch - 5ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.3138 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.3734 - val_sparse_categorical_accuracy: 0.8674 - 1s/epoch - 5ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.3115 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.3742 - val_sparse_categorical_accuracy: 0.8671 - 1s/epoch - 5ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.3093 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.3727 - val_sparse_categorical_accuracy: 0.8690 - 1s/epoch - 5ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.3071 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.3715 - val_sparse_categorical_accuracy: 0.8675 - 1s/epoch - 5ms/step
# Epoch 35/100
# 235/235 - 1s - loss: 0.3055 - sparse_categorical_accuracy: 0.8923 - val_loss: 0.3702 - val_sparse_categorical_accuracy: 0.8684 - 1s/epoch - 5ms/step
# Epoch 36/100
# 235/235 - 1s - loss: 0.3034 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.3687 - val_sparse_categorical_accuracy: 0.8688 - 1s/epoch - 5ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.3011 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3713 - val_sparse_categorical_accuracy: 0.8676 - 1s/epoch - 5ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.2993 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.3675 - val_sparse_categorical_accuracy: 0.8706 - 1s/epoch - 5ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.2975 - sparse_categorical_accuracy: 0.8960 - val_loss: 0.3663 - val_sparse_categorical_accuracy: 0.8705 - 1s/epoch - 5ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.2955 - sparse_categorical_accuracy: 0.8963 - val_loss: 0.3657 - val_sparse_categorical_accuracy: 0.8703 - 1s/epoch - 5ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.2938 - sparse_categorical_accuracy: 0.8963 - val_loss: 0.3614 - val_sparse_categorical_accuracy: 0.8732 - 1s/epoch - 5ms/step
# Epoch 42/100
# 235/235 - 1s - loss: 0.2922 - sparse_categorical_accuracy: 0.8975 - val_loss: 0.3607 - val_sparse_categorical_accuracy: 0.8725 - 1s/epoch - 5ms/step
# Epoch 43/100
# 235/235 - 1s - loss: 0.2904 - sparse_categorical_accuracy: 0.8977 - val_loss: 0.3627 - val_sparse_categorical_accuracy: 0.8734 - 1s/epoch - 5ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.2885 - sparse_categorical_accuracy: 0.8985 - val_loss: 0.3595 - val_sparse_categorical_accuracy: 0.8738 - 1s/epoch - 5ms/step
# Epoch 45/100
# 235/235 - 1s - loss: 0.2868 - sparse_categorical_accuracy: 0.8988 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.8741 - 1s/epoch - 5ms/step
# Epoch 46/100
# 235/235 - 1s - loss: 0.2851 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.3574 - val_sparse_categorical_accuracy: 0.8738 - 1s/epoch - 5ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.2835 - sparse_categorical_accuracy: 0.9005 - val_loss: 0.3588 - val_sparse_categorical_accuracy: 0.8732 - 1s/epoch - 5ms/step
# Epoch 48/100
# 235/235 - 1s - loss: 0.2822 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.8734 - 1s/epoch - 5ms/step
# Epoch 49/100
# 235/235 - 1s - loss: 0.2805 - sparse_categorical_accuracy: 0.9013 - val_loss: 0.3604 - val_sparse_categorical_accuracy: 0.8729 - 1s/epoch - 5ms/step
# Epoch 50/100
# 235/235 - 1s - loss: 0.2784 - sparse_categorical_accuracy: 0.9018 - val_loss: 0.3597 - val_sparse_categorical_accuracy: 0.8737 - 1s/epoch - 5ms/step
# Epoch 51/100
# 235/235 - 1s - loss: 0.2775 - sparse_categorical_accuracy: 0.9024 - val_loss: 0.3538 - val_sparse_categorical_accuracy: 0.8746 - 1s/epoch - 5ms/step
# Epoch 52/100
# 235/235 - 1s - loss: 0.2757 - sparse_categorical_accuracy: 0.9033 - val_loss: 0.3518 - val_sparse_categorical_accuracy: 0.8774 - 1s/epoch - 5ms/step
# Epoch 53/100
# 235/235 - 1s - loss: 0.2743 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.8730 - 1s/epoch - 5ms/step
# Epoch 54/100
# 235/235 - 1s - loss: 0.2726 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.3558 - val_sparse_categorical_accuracy: 0.8729 - 1s/epoch - 5ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.2712 - sparse_categorical_accuracy: 0.9044 - val_loss: 0.3502 - val_sparse_categorical_accuracy: 0.8777 - 1s/epoch - 5ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.2700 - sparse_categorical_accuracy: 0.9055 - val_loss: 0.3499 - val_sparse_categorical_accuracy: 0.8759 - 1s/epoch - 5ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.2686 - sparse_categorical_accuracy: 0.9064 - val_loss: 0.3492 - val_sparse_categorical_accuracy: 0.8770 - 1s/epoch - 5ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.2667 - sparse_categorical_accuracy: 0.9061 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 0.8773 - 1s/epoch - 5ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.2656 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.3500 - val_sparse_categorical_accuracy: 0.8768 - 1s/epoch - 5ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.2642 - sparse_categorical_accuracy: 0.9076 - val_loss: 0.3467 - val_sparse_categorical_accuracy: 0.8771 - 1s/epoch - 5ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.2629 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 62/100
# 235/235 - 1s - loss: 0.2615 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.3479 - val_sparse_categorical_accuracy: 0.8759 - 1s/epoch - 5ms/step
# Epoch 63/100
# 235/235 - 1s - loss: 0.2600 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.3532 - val_sparse_categorical_accuracy: 0.8755 - 1s/epoch - 5ms/step
# Epoch 64/100
# 235/235 - 1s - loss: 0.2592 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.3436 - val_sparse_categorical_accuracy: 0.8789 - 1s/epoch - 5ms/step
# Epoch 65/100
# 235/235 - 1s - loss: 0.2579 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.3440 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 66/100
# 235/235 - 1s - loss: 0.2563 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.3433 - val_sparse_categorical_accuracy: 0.8765 - 1s/epoch - 5ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.2551 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8803 - 1s/epoch - 5ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.2538 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.3426 - val_sparse_categorical_accuracy: 0.8794 - 1s/epoch - 5ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.2529 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.3478 - val_sparse_categorical_accuracy: 0.8749 - 1s/epoch - 5ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.2515 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.8761 - 1s/epoch - 4ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.2501 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8805 - 1s/epoch - 5ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.2491 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8790 - 1s/epoch - 4ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.2482 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.3396 - val_sparse_categorical_accuracy: 0.8786 - 1s/epoch - 5ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.2466 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8812 - 1s/epoch - 5ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.2457 - sparse_categorical_accuracy: 0.9143 - val_loss: 0.3452 - val_sparse_categorical_accuracy: 0.8771 - 1s/epoch - 5ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.2445 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8806 - 1s/epoch - 5ms/step
# Epoch 77/100
# 235/235 - 1s - loss: 0.2433 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.3380 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 78/100
# 235/235 - 1s - loss: 0.2421 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.3395 - val_sparse_categorical_accuracy: 0.8793 - 1s/epoch - 5ms/step
# Epoch 79/100
# 235/235 - 1s - loss: 0.2408 - sparse_categorical_accuracy: 0.9163 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.8810 - 1s/epoch - 5ms/step
# Epoch 80/100
# 235/235 - 1s - loss: 0.2399 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8814 - 1s/epoch - 5ms/step
# Epoch 81/100
# 235/235 - 1s - loss: 0.2387 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.3394 - val_sparse_categorical_accuracy: 0.8802 - 1s/epoch - 5ms/step
# Epoch 82/100
# 235/235 - 1s - loss: 0.2376 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 83/100
# 235/235 - 1s - loss: 0.2365 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.3357 - val_sparse_categorical_accuracy: 0.8821 - 1s/epoch - 5ms/step
# Epoch 84/100
# 235/235 - 1s - loss: 0.2357 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.3365 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 85/100
# 235/235 - 1s - loss: 0.2342 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3466 - val_sparse_categorical_accuracy: 0.8777 - 1s/epoch - 5ms/step
# Epoch 86/100
# 235/235 - 1s - loss: 0.2334 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.3380 - val_sparse_categorical_accuracy: 0.8795 - 1s/epoch - 5ms/step
# Epoch 87/100
# 235/235 - 1s - loss: 0.2327 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8813 - 1s/epoch - 5ms/step
# Epoch 88/100
# 235/235 - 1s - loss: 0.2317 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8802 - 1s/epoch - 5ms/step
# Epoch 89/100
# 235/235 - 1s - loss: 0.2304 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8825 - 1s/epoch - 5ms/step
# Epoch 90/100
# 235/235 - 1s - loss: 0.2293 - sparse_categorical_accuracy: 0.9203 - val_loss: 0.3378 - val_sparse_categorical_accuracy: 0.8797 - 1s/epoch - 5ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.2283 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.3333 - val_sparse_categorical_accuracy: 0.8837 - 1s/epoch - 5ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.2275 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.3325 - val_sparse_categorical_accuracy: 0.8823 - 1s/epoch - 5ms/step
# Epoch 93/100
# 235/235 - 1s - loss: 0.2261 - sparse_categorical_accuracy: 0.9211 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8805 - 1s/epoch - 5ms/step
# Epoch 94/100
# 235/235 - 1s - loss: 0.2256 - sparse_categorical_accuracy: 0.9214 - val_loss: 0.3326 - val_sparse_categorical_accuracy: 0.8841 - 1s/epoch - 5ms/step
# Epoch 95/100
# 235/235 - 1s - loss: 0.2242 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.3301 - val_sparse_categorical_accuracy: 0.8839 - 1s/epoch - 5ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.2234 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.3398 - val_sparse_categorical_accuracy: 0.8795 - 1s/epoch - 5ms/step
# Epoch 97/100
# 235/235 - 1s - loss: 0.2227 - sparse_categorical_accuracy: 0.9231 - val_loss: 0.3408 - val_sparse_categorical_accuracy: 0.8782 - 1s/epoch - 5ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.2214 - sparse_categorical_accuracy: 0.9234 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8832 - 1s/epoch - 5ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.2210 - sparse_categorical_accuracy: 0.9235 - val_loss: 0.3363 - val_sparse_categorical_accuracy: 0.8808 - 1s/epoch - 5ms/step
# Epoch 100/100
# 235/235 - 1s - loss: 0.2195 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.3338 - val_sparse_categorical_accuracy: 0.8816 - 1s/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
