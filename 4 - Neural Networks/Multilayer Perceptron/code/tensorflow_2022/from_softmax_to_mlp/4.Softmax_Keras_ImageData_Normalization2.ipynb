# %%
import numpy as np
import gzip

# load training images
with gzip.open('data_fashion_mnist/train-images-idx3-ubyte.gz', 'rb') as f:
    X_train = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load testing images
with gzip.open('data_fashion_mnist/t10k-images-idx3-ubyte.gz', 'rb') as f:
    X_test = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load training labels
with gzip.open('data_fashion_mnist/train-labels-idx1-ubyte.gz', 'rb') as f:
    y_train = np.frombuffer(f.read(), np.uint8, offset=8)
    
# load testing labels
with gzip.open('data_fashion_mnist/t10k-labels-idx1-ubyte.gz', 'rb') as f:
    y_test = np.frombuffer(f.read(), np.uint8, offset=8)
    

# check data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')

# %%
# data normalization
mean = np.mean(X_train)
std  = np.std(X_train)

X_train = (X_train-mean)/std
X_test  = (X_test-mean)/std

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                7850
#
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 1s - loss: 0.8619 - sparse_categorical_accuracy: 0.6998 - val_loss: 0.6622 - val_sparse_categorical_accuracy: 0.7649 - 826ms/epoch - 4ms/step
# Epoch 2/100
# 235/235 - 1s - loss: 0.6008 - sparse_categorical_accuracy: 0.7892 - val_loss: 0.5929 - val_sparse_categorical_accuracy: 0.7917 - 516ms/epoch - 2ms/step
# Epoch 3/100
# 235/235 - 0s - loss: 0.5498 - sparse_categorical_accuracy: 0.8088 - val_loss: 0.5599 - val_sparse_categorical_accuracy: 0.8031 - 482ms/epoch - 2ms/step
# Epoch 4/100
# 235/235 - 0s - loss: 0.5232 - sparse_categorical_accuracy: 0.8189 - val_loss: 0.5413 - val_sparse_categorical_accuracy: 0.8118 - 500ms/epoch - 2ms/step
# Epoch 5/100
# 235/235 - 0s - loss: 0.5052 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.5275 - val_sparse_categorical_accuracy: 0.8175 - 499ms/epoch - 2ms/step
# Epoch 6/100
# 235/235 - 1s - loss: 0.4925 - sparse_categorical_accuracy: 0.8301 - val_loss: 0.5167 - val_sparse_categorical_accuracy: 0.8215 - 524ms/epoch - 2ms/step
# Epoch 7/100
# 235/235 - 1s - loss: 0.4827 - sparse_categorical_accuracy: 0.8336 - val_loss: 0.5113 - val_sparse_categorical_accuracy: 0.8241 - 515ms/epoch - 2ms/step
# Epoch 8/100
# 235/235 - 0s - loss: 0.4749 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.5037 - val_sparse_categorical_accuracy: 0.8228 - 484ms/epoch - 2ms/step
# Epoch 9/100
# 235/235 - 0s - loss: 0.4682 - sparse_categorical_accuracy: 0.8389 - val_loss: 0.5004 - val_sparse_categorical_accuracy: 0.8244 - 493ms/epoch - 2ms/step
# Epoch 10/100
# 235/235 - 0s - loss: 0.4628 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.4971 - val_sparse_categorical_accuracy: 0.8259 - 483ms/epoch - 2ms/step
# Epoch 11/100
# 235/235 - 1s - loss: 0.4578 - sparse_categorical_accuracy: 0.8429 - val_loss: 0.4907 - val_sparse_categorical_accuracy: 0.8286 - 541ms/epoch - 2ms/step
# Epoch 12/100
# 235/235 - 1s - loss: 0.4537 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.4872 - val_sparse_categorical_accuracy: 0.8285 - 529ms/epoch - 2ms/step
# Epoch 13/100
# 235/235 - 1s - loss: 0.4499 - sparse_categorical_accuracy: 0.8450 - val_loss: 0.4834 - val_sparse_categorical_accuracy: 0.8316 - 529ms/epoch - 2ms/step
# Epoch 14/100
# 235/235 - 1s - loss: 0.4466 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.4802 - val_sparse_categorical_accuracy: 0.8323 - 533ms/epoch - 2ms/step
# Epoch 15/100
# 235/235 - 1s - loss: 0.4436 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.4782 - val_sparse_categorical_accuracy: 0.8336 - 520ms/epoch - 2ms/step
# Epoch 16/100
# 235/235 - 0s - loss: 0.4409 - sparse_categorical_accuracy: 0.8474 - val_loss: 0.4771 - val_sparse_categorical_accuracy: 0.8329 - 498ms/epoch - 2ms/step
# Epoch 17/100
# 235/235 - 1s - loss: 0.4383 - sparse_categorical_accuracy: 0.8492 - val_loss: 0.4768 - val_sparse_categorical_accuracy: 0.8335 - 500ms/epoch - 2ms/step
# Epoch 18/100
# 235/235 - 0s - loss: 0.4360 - sparse_categorical_accuracy: 0.8496 - val_loss: 0.4730 - val_sparse_categorical_accuracy: 0.8357 - 485ms/epoch - 2ms/step
# Epoch 19/100
# 235/235 - 1s - loss: 0.4340 - sparse_categorical_accuracy: 0.8493 - val_loss: 0.4715 - val_sparse_categorical_accuracy: 0.8354 - 510ms/epoch - 2ms/step
# Epoch 20/100
# 235/235 - 0s - loss: 0.4320 - sparse_categorical_accuracy: 0.8508 - val_loss: 0.4702 - val_sparse_categorical_accuracy: 0.8357 - 485ms/epoch - 2ms/step
# Epoch 21/100
# 235/235 - 0s - loss: 0.4301 - sparse_categorical_accuracy: 0.8519 - val_loss: 0.4681 - val_sparse_categorical_accuracy: 0.8359 - 498ms/epoch - 2ms/step
# Epoch 22/100
# 235/235 - 0s - loss: 0.4284 - sparse_categorical_accuracy: 0.8526 - val_loss: 0.4690 - val_sparse_categorical_accuracy: 0.8336 - 485ms/epoch - 2ms/step
# Epoch 23/100
# 235/235 - 0s - loss: 0.4265 - sparse_categorical_accuracy: 0.8540 - val_loss: 0.4669 - val_sparse_categorical_accuracy: 0.8357 - 498ms/epoch - 2ms/step
# Epoch 24/100
# 235/235 - 0s - loss: 0.4254 - sparse_categorical_accuracy: 0.8537 - val_loss: 0.4643 - val_sparse_categorical_accuracy: 0.8361 - 485ms/epoch - 2ms/step
# Epoch 25/100
# 235/235 - 0s - loss: 0.4238 - sparse_categorical_accuracy: 0.8536 - val_loss: 0.4646 - val_sparse_categorical_accuracy: 0.8355 - 498ms/epoch - 2ms/step
# Epoch 26/100
# 235/235 - 1s - loss: 0.4223 - sparse_categorical_accuracy: 0.8548 - val_loss: 0.4652 - val_sparse_categorical_accuracy: 0.8340 - 502ms/epoch - 2ms/step
# Epoch 27/100
# 235/235 - 0s - loss: 0.4210 - sparse_categorical_accuracy: 0.8553 - val_loss: 0.4624 - val_sparse_categorical_accuracy: 0.8357 - 492ms/epoch - 2ms/step
# Epoch 28/100
# 235/235 - 1s - loss: 0.4196 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.4609 - val_sparse_categorical_accuracy: 0.8371 - 505ms/epoch - 2ms/step
# Epoch 29/100
# 235/235 - 1s - loss: 0.4188 - sparse_categorical_accuracy: 0.8566 - val_loss: 0.4607 - val_sparse_categorical_accuracy: 0.8360 - 554ms/epoch - 2ms/step
# Epoch 30/100
# 235/235 - 1s - loss: 0.4174 - sparse_categorical_accuracy: 0.8558 - val_loss: 0.4597 - val_sparse_categorical_accuracy: 0.8390 - 549ms/epoch - 2ms/step
# Epoch 31/100
# 235/235 - 1s - loss: 0.4164 - sparse_categorical_accuracy: 0.8564 - val_loss: 0.4591 - val_sparse_categorical_accuracy: 0.8367 - 534ms/epoch - 2ms/step
# Epoch 32/100
# 235/235 - 1s - loss: 0.4153 - sparse_categorical_accuracy: 0.8572 - val_loss: 0.4592 - val_sparse_categorical_accuracy: 0.8357 - 571ms/epoch - 2ms/step
# Epoch 33/100
# 235/235 - 1s - loss: 0.4144 - sparse_categorical_accuracy: 0.8575 - val_loss: 0.4578 - val_sparse_categorical_accuracy: 0.8395 - 551ms/epoch - 2ms/step
# Epoch 34/100
# 235/235 - 1s - loss: 0.4133 - sparse_categorical_accuracy: 0.8574 - val_loss: 0.4565 - val_sparse_categorical_accuracy: 0.8396 - 523ms/epoch - 2ms/step
# Epoch 35/100
# 235/235 - 0s - loss: 0.4125 - sparse_categorical_accuracy: 0.8580 - val_loss: 0.4563 - val_sparse_categorical_accuracy: 0.8376 - 492ms/epoch - 2ms/step
# Epoch 36/100
# 235/235 - 0s - loss: 0.4115 - sparse_categorical_accuracy: 0.8583 - val_loss: 0.4554 - val_sparse_categorical_accuracy: 0.8396 - 474ms/epoch - 2ms/step
# Epoch 37/100
# 235/235 - 1s - loss: 0.4107 - sparse_categorical_accuracy: 0.8582 - val_loss: 0.4559 - val_sparse_categorical_accuracy: 0.8385 - 519ms/epoch - 2ms/step
# Epoch 38/100
# 235/235 - 1s - loss: 0.4102 - sparse_categorical_accuracy: 0.8590 - val_loss: 0.4534 - val_sparse_categorical_accuracy: 0.8395 - 528ms/epoch - 2ms/step
# Epoch 39/100
# 235/235 - 1s - loss: 0.4089 - sparse_categorical_accuracy: 0.8590 - val_loss: 0.4548 - val_sparse_categorical_accuracy: 0.8387 - 513ms/epoch - 2ms/step
# Epoch 40/100
# 235/235 - 1s - loss: 0.4083 - sparse_categorical_accuracy: 0.8596 - val_loss: 0.4529 - val_sparse_categorical_accuracy: 0.8386 - 504ms/epoch - 2ms/step
# Epoch 41/100
# 235/235 - 1s - loss: 0.4076 - sparse_categorical_accuracy: 0.8593 - val_loss: 0.4518 - val_sparse_categorical_accuracy: 0.8392 - 519ms/epoch - 2ms/step
# Epoch 42/100
# 235/235 - 0s - loss: 0.4068 - sparse_categorical_accuracy: 0.8605 - val_loss: 0.4527 - val_sparse_categorical_accuracy: 0.8368 - 491ms/epoch - 2ms/step
# Epoch 43/100
# 235/235 - 0s - loss: 0.4061 - sparse_categorical_accuracy: 0.8606 - val_loss: 0.4513 - val_sparse_categorical_accuracy: 0.8401 - 495ms/epoch - 2ms/step
# Epoch 44/100
# 235/235 - 1s - loss: 0.4055 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.4518 - val_sparse_categorical_accuracy: 0.8402 - 518ms/epoch - 2ms/step
# Epoch 45/100
# 235/235 - 0s - loss: 0.4048 - sparse_categorical_accuracy: 0.8606 - val_loss: 0.4508 - val_sparse_categorical_accuracy: 0.8402 - 475ms/epoch - 2ms/step
# Epoch 46/100
# 235/235 - 0s - loss: 0.4041 - sparse_categorical_accuracy: 0.8602 - val_loss: 0.4527 - val_sparse_categorical_accuracy: 0.8398 - 495ms/epoch - 2ms/step
# Epoch 47/100
# 235/235 - 1s - loss: 0.4036 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.4497 - val_sparse_categorical_accuracy: 0.8392 - 516ms/epoch - 2ms/step
# Epoch 48/100
# 235/235 - 0s - loss: 0.4028 - sparse_categorical_accuracy: 0.8617 - val_loss: 0.4532 - val_sparse_categorical_accuracy: 0.8399 - 492ms/epoch - 2ms/step
# Epoch 49/100
# 235/235 - 0s - loss: 0.4023 - sparse_categorical_accuracy: 0.8615 - val_loss: 0.4514 - val_sparse_categorical_accuracy: 0.8406 - 484ms/epoch - 2ms/step
# Epoch 50/100
# 235/235 - 0s - loss: 0.4017 - sparse_categorical_accuracy: 0.8617 - val_loss: 0.4508 - val_sparse_categorical_accuracy: 0.8402 - 499ms/epoch - 2ms/step
# Epoch 51/100
# 235/235 - 0s - loss: 0.4013 - sparse_categorical_accuracy: 0.8619 - val_loss: 0.4493 - val_sparse_categorical_accuracy: 0.8405 - 485ms/epoch - 2ms/step
# Epoch 52/100
# 235/235 - 0s - loss: 0.4008 - sparse_categorical_accuracy: 0.8621 - val_loss: 0.4485 - val_sparse_categorical_accuracy: 0.8394 - 483ms/epoch - 2ms/step
# Epoch 53/100
# 235/235 - 0s - loss: 0.4001 - sparse_categorical_accuracy: 0.8619 - val_loss: 0.4480 - val_sparse_categorical_accuracy: 0.8400 - 484ms/epoch - 2ms/step
# Epoch 54/100
# 235/235 - 0s - loss: 0.3997 - sparse_categorical_accuracy: 0.8621 - val_loss: 0.4495 - val_sparse_categorical_accuracy: 0.8391 - 483ms/epoch - 2ms/step
# Epoch 55/100
# 235/235 - 1s - loss: 0.3991 - sparse_categorical_accuracy: 0.8630 - val_loss: 0.4486 - val_sparse_categorical_accuracy: 0.8387 - 521ms/epoch - 2ms/step
# Epoch 56/100
# 235/235 - 1s - loss: 0.3985 - sparse_categorical_accuracy: 0.8629 - val_loss: 0.4477 - val_sparse_categorical_accuracy: 0.8391 - 502ms/epoch - 2ms/step
# Epoch 57/100
# 235/235 - 1s - loss: 0.3980 - sparse_categorical_accuracy: 0.8629 - val_loss: 0.4498 - val_sparse_categorical_accuracy: 0.8396 - 566ms/epoch - 2ms/step
# Epoch 58/100
# 235/235 - 1s - loss: 0.3977 - sparse_categorical_accuracy: 0.8630 - val_loss: 0.4457 - val_sparse_categorical_accuracy: 0.8408 - 501ms/epoch - 2ms/step
# Epoch 59/100
# 235/235 - 1s - loss: 0.3974 - sparse_categorical_accuracy: 0.8634 - val_loss: 0.4474 - val_sparse_categorical_accuracy: 0.8415 - 509ms/epoch - 2ms/step
# Epoch 60/100
# 235/235 - 1s - loss: 0.3966 - sparse_categorical_accuracy: 0.8632 - val_loss: 0.4463 - val_sparse_categorical_accuracy: 0.8409 - 507ms/epoch - 2ms/step
# Epoch 61/100
# 235/235 - 1s - loss: 0.3962 - sparse_categorical_accuracy: 0.8638 - val_loss: 0.4452 - val_sparse_categorical_accuracy: 0.8422 - 510ms/epoch - 2ms/step
# Epoch 62/100
# 235/235 - 0s - loss: 0.3959 - sparse_categorical_accuracy: 0.8632 - val_loss: 0.4454 - val_sparse_categorical_accuracy: 0.8407 - 493ms/epoch - 2ms/step
# Epoch 63/100
# 235/235 - 0s - loss: 0.3953 - sparse_categorical_accuracy: 0.8639 - val_loss: 0.4484 - val_sparse_categorical_accuracy: 0.8419 - 475ms/epoch - 2ms/step
# Epoch 64/100
# 235/235 - 0s - loss: 0.3950 - sparse_categorical_accuracy: 0.8636 - val_loss: 0.4446 - val_sparse_categorical_accuracy: 0.8423 - 472ms/epoch - 2ms/step
# Epoch 65/100
# 235/235 - 0s - loss: 0.3945 - sparse_categorical_accuracy: 0.8637 - val_loss: 0.4498 - val_sparse_categorical_accuracy: 0.8394 - 497ms/epoch - 2ms/step
# Epoch 66/100
# 235/235 - 0s - loss: 0.3940 - sparse_categorical_accuracy: 0.8638 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.8416 - 499ms/epoch - 2ms/step
# Epoch 67/100
# 235/235 - 1s - loss: 0.3937 - sparse_categorical_accuracy: 0.8641 - val_loss: 0.4450 - val_sparse_categorical_accuracy: 0.8424 - 509ms/epoch - 2ms/step
# Epoch 68/100
# 235/235 - 1s - loss: 0.3933 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.4438 - val_sparse_categorical_accuracy: 0.8424 - 508ms/epoch - 2ms/step
# Epoch 69/100
# 235/235 - 1s - loss: 0.3929 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.4479 - val_sparse_categorical_accuracy: 0.8388 - 544ms/epoch - 2ms/step
# Epoch 70/100
# 235/235 - 1s - loss: 0.3925 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.4442 - val_sparse_categorical_accuracy: 0.8424 - 535ms/epoch - 2ms/step
# Epoch 71/100
# 235/235 - 1s - loss: 0.3922 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.4457 - val_sparse_categorical_accuracy: 0.8404 - 610ms/epoch - 3ms/step
# Epoch 72/100
# 235/235 - 1s - loss: 0.3916 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.8428 - 523ms/epoch - 2ms/step
# Epoch 73/100
# 235/235 - 1s - loss: 0.3913 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.4454 - val_sparse_categorical_accuracy: 0.8423 - 563ms/epoch - 2ms/step
# Epoch 74/100
# 235/235 - 1s - loss: 0.3912 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.4431 - val_sparse_categorical_accuracy: 0.8429 - 523ms/epoch - 2ms/step
# Epoch 75/100
# 235/235 - 1s - loss: 0.3908 - sparse_categorical_accuracy: 0.8649 - val_loss: 0.4469 - val_sparse_categorical_accuracy: 0.8398 - 526ms/epoch - 2ms/step
# Epoch 76/100
# 235/235 - 1s - loss: 0.3905 - sparse_categorical_accuracy: 0.8649 - val_loss: 0.4443 - val_sparse_categorical_accuracy: 0.8432 - 522ms/epoch - 2ms/step
# Epoch 77/100
# 235/235 - 0s - loss: 0.3900 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.4453 - val_sparse_categorical_accuracy: 0.8399 - 490ms/epoch - 2ms/step
# Epoch 78/100
# 235/235 - 0s - loss: 0.3901 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.4430 - val_sparse_categorical_accuracy: 0.8430 - 475ms/epoch - 2ms/step
# Epoch 79/100
# 235/235 - 0s - loss: 0.3894 - sparse_categorical_accuracy: 0.8657 - val_loss: 0.4438 - val_sparse_categorical_accuracy: 0.8421 - 469ms/epoch - 2ms/step
# Epoch 80/100
# 235/235 - 0s - loss: 0.3894 - sparse_categorical_accuracy: 0.8657 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.8413 - 484ms/epoch - 2ms/step
# Epoch 81/100
# 235/235 - 0s - loss: 0.3889 - sparse_categorical_accuracy: 0.8658 - val_loss: 0.4439 - val_sparse_categorical_accuracy: 0.8413 - 484ms/epoch - 2ms/step
# Epoch 82/100
# 235/235 - 0s - loss: 0.3887 - sparse_categorical_accuracy: 0.8655 - val_loss: 0.4429 - val_sparse_categorical_accuracy: 0.8415 - 469ms/epoch - 2ms/step
# Epoch 83/100
# 235/235 - 0s - loss: 0.3882 - sparse_categorical_accuracy: 0.8666 - val_loss: 0.4418 - val_sparse_categorical_accuracy: 0.8425 - 484ms/epoch - 2ms/step
# Epoch 84/100
# 235/235 - 0s - loss: 0.3880 - sparse_categorical_accuracy: 0.8661 - val_loss: 0.4432 - val_sparse_categorical_accuracy: 0.8425 - 469ms/epoch - 2ms/step
# Epoch 85/100
# 235/235 - 0s - loss: 0.3877 - sparse_categorical_accuracy: 0.8657 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.8414 - 484ms/epoch - 2ms/step
# Epoch 86/100
# 235/235 - 0s - loss: 0.3877 - sparse_categorical_accuracy: 0.8665 - val_loss: 0.4415 - val_sparse_categorical_accuracy: 0.8424 - 484ms/epoch - 2ms/step
# Epoch 87/100
# 235/235 - 0s - loss: 0.3870 - sparse_categorical_accuracy: 0.8666 - val_loss: 0.4423 - val_sparse_categorical_accuracy: 0.8433 - 484ms/epoch - 2ms/step
# Epoch 88/100
# 235/235 - 0s - loss: 0.3870 - sparse_categorical_accuracy: 0.8662 - val_loss: 0.4416 - val_sparse_categorical_accuracy: 0.8428 - 484ms/epoch - 2ms/step
# Epoch 89/100
# 235/235 - 0s - loss: 0.3866 - sparse_categorical_accuracy: 0.8661 - val_loss: 0.4418 - val_sparse_categorical_accuracy: 0.8423 - 469ms/epoch - 2ms/step
# Epoch 90/100
# 235/235 - 0s - loss: 0.3865 - sparse_categorical_accuracy: 0.8666 - val_loss: 0.4405 - val_sparse_categorical_accuracy: 0.8425 - 469ms/epoch - 2ms/step
# Epoch 91/100
# 235/235 - 1s - loss: 0.3861 - sparse_categorical_accuracy: 0.8662 - val_loss: 0.4409 - val_sparse_categorical_accuracy: 0.8425 - 558ms/epoch - 2ms/step
# Epoch 92/100
# 235/235 - 1s - loss: 0.3858 - sparse_categorical_accuracy: 0.8669 - val_loss: 0.4408 - val_sparse_categorical_accuracy: 0.8433 - 520ms/epoch - 2ms/step
# Epoch 93/100
# 235/235 - 0s - loss: 0.3856 - sparse_categorical_accuracy: 0.8667 - val_loss: 0.4411 - val_sparse_categorical_accuracy: 0.8432 - 474ms/epoch - 2ms/step
# Epoch 94/100
# 235/235 - 0s - loss: 0.3855 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.4402 - val_sparse_categorical_accuracy: 0.8435 - 484ms/epoch - 2ms/step
# Epoch 95/100
# 235/235 - 0s - loss: 0.3849 - sparse_categorical_accuracy: 0.8668 - val_loss: 0.4401 - val_sparse_categorical_accuracy: 0.8433 - 484ms/epoch - 2ms/step
# Epoch 96/100
# 235/235 - 1s - loss: 0.3847 - sparse_categorical_accuracy: 0.8668 - val_loss: 0.4415 - val_sparse_categorical_accuracy: 0.8432 - 519ms/epoch - 2ms/step
# Epoch 97/100
# 235/235 - 0s - loss: 0.3846 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.4408 - val_sparse_categorical_accuracy: 0.8427 - 478ms/epoch - 2ms/step
# Epoch 98/100
# 235/235 - 1s - loss: 0.3841 - sparse_categorical_accuracy: 0.8675 - val_loss: 0.4439 - val_sparse_categorical_accuracy: 0.8404 - 533ms/epoch - 2ms/step
# Epoch 99/100
# 235/235 - 1s - loss: 0.3840 - sparse_categorical_accuracy: 0.8675 - val_loss: 0.4430 - val_sparse_categorical_accuracy: 0.8422 - 506ms/epoch - 2ms/step
# Epoch 100/100
# 235/235 - 0s - loss: 0.3838 - sparse_categorical_accuracy: 0.8676 - val_loss: 0.4396 - val_sparse_categorical_accuracy: 0.8437 - 479ms/epoch - 2ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
