# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')

x_train = tf.reshape(x_train, (-1, 28*28))
x_test  = tf.reshape(x_test, (-1, 28*28))

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)

# %%
# data normalization

mean = np.mean(x_train)
std  = np.std(x_train)

x_train = (x_train-mean)/std
x_test  = (x_test-mean)/std

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 256)               200960
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(x_train, y_train, 
                    validation_data=(x_test, y_test), 
                    batch_size=256, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 3s - loss: 0.8097 - sparse_categorical_accuracy: 0.7297 - val_loss: 0.6234 - val_sparse_categorical_accuracy: 0.7868 - 3s/epoch - 11ms/step
# Epoch 2/100
# 235/235 - 2s - loss: 0.5519 - sparse_categorical_accuracy: 0.8079 - val_loss: 0.5510 - val_sparse_categorical_accuracy: 0.8056 - 2s/epoch - 7ms/step
# Epoch 3/100
# 235/235 - 2s - loss: 0.4981 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.5329 - val_sparse_categorical_accuracy: 0.8045 - 2s/epoch - 7ms/step
# Epoch 4/100
# 235/235 - 2s - loss: 0.4685 - sparse_categorical_accuracy: 0.8360 - val_loss: 0.4960 - val_sparse_categorical_accuracy: 0.8226 - 2s/epoch - 7ms/step
# Epoch 5/100
# 235/235 - 2s - loss: 0.4483 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.4802 - val_sparse_categorical_accuracy: 0.8290 - 2s/epoch - 7ms/step
# Epoch 6/100
# 235/235 - 2s - loss: 0.4328 - sparse_categorical_accuracy: 0.8488 - val_loss: 0.4660 - val_sparse_categorical_accuracy: 0.8325 - 2s/epoch - 8ms/step
# Epoch 7/100
# 235/235 - 2s - loss: 0.4205 - sparse_categorical_accuracy: 0.8523 - val_loss: 0.4574 - val_sparse_categorical_accuracy: 0.8373 - 2s/epoch - 8ms/step
# Epoch 8/100
# 235/235 - 2s - loss: 0.4105 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.4467 - val_sparse_categorical_accuracy: 0.8408 - 2s/epoch - 7ms/step
# Epoch 9/100
# 235/235 - 2s - loss: 0.4019 - sparse_categorical_accuracy: 0.8585 - val_loss: 0.4453 - val_sparse_categorical_accuracy: 0.8398 - 2s/epoch - 8ms/step
# Epoch 10/100
# 235/235 - 2s - loss: 0.3942 - sparse_categorical_accuracy: 0.8609 - val_loss: 0.4365 - val_sparse_categorical_accuracy: 0.8455 - 2s/epoch - 7ms/step
# Epoch 11/100
# 235/235 - 2s - loss: 0.3880 - sparse_categorical_accuracy: 0.8637 - val_loss: 0.4362 - val_sparse_categorical_accuracy: 0.8439 - 2s/epoch - 7ms/step
# Epoch 12/100
# 235/235 - 2s - loss: 0.3822 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.4294 - val_sparse_categorical_accuracy: 0.8467 - 2s/epoch - 7ms/step
# Epoch 13/100
# 235/235 - 2s - loss: 0.3766 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.4224 - val_sparse_categorical_accuracy: 0.8487 - 2s/epoch - 7ms/step
# Epoch 14/100
# 235/235 - 2s - loss: 0.3715 - sparse_categorical_accuracy: 0.8685 - val_loss: 0.4218 - val_sparse_categorical_accuracy: 0.8491 - 2s/epoch - 7ms/step
# Epoch 15/100
# 235/235 - 2s - loss: 0.3668 - sparse_categorical_accuracy: 0.8702 - val_loss: 0.4139 - val_sparse_categorical_accuracy: 0.8517 - 2s/epoch - 7ms/step
# Epoch 16/100
# 235/235 - 2s - loss: 0.3623 - sparse_categorical_accuracy: 0.8723 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.8519 - 2s/epoch - 7ms/step
# Epoch 17/100
# 235/235 - 2s - loss: 0.3582 - sparse_categorical_accuracy: 0.8733 - val_loss: 0.4064 - val_sparse_categorical_accuracy: 0.8554 - 2s/epoch - 7ms/step
# Epoch 18/100
# 235/235 - 2s - loss: 0.3544 - sparse_categorical_accuracy: 0.8752 - val_loss: 0.4055 - val_sparse_categorical_accuracy: 0.8535 - 2s/epoch - 7ms/step
# Epoch 19/100
# 235/235 - 2s - loss: 0.3508 - sparse_categorical_accuracy: 0.8756 - val_loss: 0.4016 - val_sparse_categorical_accuracy: 0.8575 - 2s/epoch - 7ms/step
# Epoch 20/100
# 235/235 - 2s - loss: 0.3476 - sparse_categorical_accuracy: 0.8772 - val_loss: 0.3979 - val_sparse_categorical_accuracy: 0.8553 - 2s/epoch - 7ms/step
# Epoch 21/100
# 235/235 - 2s - loss: 0.3442 - sparse_categorical_accuracy: 0.8780 - val_loss: 0.3961 - val_sparse_categorical_accuracy: 0.8577 - 2s/epoch - 7ms/step
# Epoch 22/100
# 235/235 - 2s - loss: 0.3410 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.4018 - val_sparse_categorical_accuracy: 0.8587 - 2s/epoch - 7ms/step
# Epoch 23/100
# 235/235 - 2s - loss: 0.3378 - sparse_categorical_accuracy: 0.8809 - val_loss: 0.3921 - val_sparse_categorical_accuracy: 0.8612 - 2s/epoch - 7ms/step
# Epoch 24/100
# 235/235 - 2s - loss: 0.3351 - sparse_categorical_accuracy: 0.8809 - val_loss: 0.3886 - val_sparse_categorical_accuracy: 0.8599 - 2s/epoch - 7ms/step
# Epoch 25/100
# 235/235 - 2s - loss: 0.3324 - sparse_categorical_accuracy: 0.8819 - val_loss: 0.3876 - val_sparse_categorical_accuracy: 0.8630 - 2s/epoch - 7ms/step
# Epoch 26/100
# 235/235 - 2s - loss: 0.3296 - sparse_categorical_accuracy: 0.8835 - val_loss: 0.3907 - val_sparse_categorical_accuracy: 0.8586 - 2s/epoch - 7ms/step
# Epoch 27/100
# 235/235 - 2s - loss: 0.3268 - sparse_categorical_accuracy: 0.8840 - val_loss: 0.3868 - val_sparse_categorical_accuracy: 0.8624 - 2s/epoch - 7ms/step
# Epoch 28/100
# 235/235 - 2s - loss: 0.3245 - sparse_categorical_accuracy: 0.8845 - val_loss: 0.3837 - val_sparse_categorical_accuracy: 0.8640 - 2s/epoch - 7ms/step
# Epoch 29/100
# 235/235 - 2s - loss: 0.3221 - sparse_categorical_accuracy: 0.8863 - val_loss: 0.3799 - val_sparse_categorical_accuracy: 0.8631 - 2s/epoch - 7ms/step
# Epoch 30/100
# 235/235 - 2s - loss: 0.3198 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3792 - val_sparse_categorical_accuracy: 0.8617 - 2s/epoch - 7ms/step
# Epoch 31/100
# 235/235 - 2s - loss: 0.3175 - sparse_categorical_accuracy: 0.8876 - val_loss: 0.3789 - val_sparse_categorical_accuracy: 0.8653 - 2s/epoch - 7ms/step
# Epoch 32/100
# 235/235 - 2s - loss: 0.3153 - sparse_categorical_accuracy: 0.8879 - val_loss: 0.3814 - val_sparse_categorical_accuracy: 0.8625 - 2s/epoch - 7ms/step
# Epoch 33/100
# 235/235 - 2s - loss: 0.3133 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.3765 - val_sparse_categorical_accuracy: 0.8635 - 2s/epoch - 7ms/step
# Epoch 34/100
# 235/235 - 2s - loss: 0.3107 - sparse_categorical_accuracy: 0.8896 - val_loss: 0.3727 - val_sparse_categorical_accuracy: 0.8675 - 2s/epoch - 7ms/step
# Epoch 35/100
# 235/235 - 2s - loss: 0.3091 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.3709 - val_sparse_categorical_accuracy: 0.8683 - 2s/epoch - 7ms/step
# Epoch 36/100
# 235/235 - 2s - loss: 0.3069 - sparse_categorical_accuracy: 0.8915 - val_loss: 0.3722 - val_sparse_categorical_accuracy: 0.8692 - 2s/epoch - 7ms/step
# Epoch 37/100
# 235/235 - 2s - loss: 0.3052 - sparse_categorical_accuracy: 0.8913 - val_loss: 0.3691 - val_sparse_categorical_accuracy: 0.8672 - 2s/epoch - 7ms/step
# Epoch 38/100
# 235/235 - 2s - loss: 0.3033 - sparse_categorical_accuracy: 0.8928 - val_loss: 0.3700 - val_sparse_categorical_accuracy: 0.8687 - 2s/epoch - 7ms/step
# Epoch 39/100
# 235/235 - 2s - loss: 0.3014 - sparse_categorical_accuracy: 0.8927 - val_loss: 0.3732 - val_sparse_categorical_accuracy: 0.8641 - 2s/epoch - 7ms/step
# Epoch 40/100
# 235/235 - 2s - loss: 0.2995 - sparse_categorical_accuracy: 0.8932 - val_loss: 0.3653 - val_sparse_categorical_accuracy: 0.8689 - 2s/epoch - 7ms/step
# Epoch 41/100
# 235/235 - 2s - loss: 0.2974 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3648 - val_sparse_categorical_accuracy: 0.8701 - 2s/epoch - 7ms/step
# Epoch 42/100
# 235/235 - 2s - loss: 0.2959 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.3657 - val_sparse_categorical_accuracy: 0.8689 - 2s/epoch - 7ms/step
# Epoch 43/100
# 235/235 - 2s - loss: 0.2938 - sparse_categorical_accuracy: 0.8959 - val_loss: 0.3692 - val_sparse_categorical_accuracy: 0.8668 - 2s/epoch - 7ms/step
# Epoch 44/100
# 235/235 - 2s - loss: 0.2926 - sparse_categorical_accuracy: 0.8964 - val_loss: 0.3670 - val_sparse_categorical_accuracy: 0.8687 - 2s/epoch - 7ms/step
# Epoch 45/100
# 235/235 - 2s - loss: 0.2905 - sparse_categorical_accuracy: 0.8975 - val_loss: 0.3630 - val_sparse_categorical_accuracy: 0.8715 - 2s/epoch - 7ms/step
# Epoch 46/100
# 235/235 - 2s - loss: 0.2892 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.3595 - val_sparse_categorical_accuracy: 0.8704 - 2s/epoch - 7ms/step
# Epoch 47/100
# 235/235 - 2s - loss: 0.2877 - sparse_categorical_accuracy: 0.8985 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.8725 - 2s/epoch - 7ms/step
# Epoch 48/100
# 235/235 - 2s - loss: 0.2858 - sparse_categorical_accuracy: 0.8988 - val_loss: 0.3576 - val_sparse_categorical_accuracy: 0.8736 - 2s/epoch - 7ms/step
# Epoch 49/100
# 235/235 - 2s - loss: 0.2841 - sparse_categorical_accuracy: 0.8991 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.8695 - 2s/epoch - 7ms/step
# Epoch 50/100
# 235/235 - 2s - loss: 0.2824 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.3556 - val_sparse_categorical_accuracy: 0.8728 - 2s/epoch - 7ms/step
# Epoch 51/100
# 235/235 - 2s - loss: 0.2810 - sparse_categorical_accuracy: 0.9002 - val_loss: 0.3647 - val_sparse_categorical_accuracy: 0.8708 - 2s/epoch - 7ms/step
# Epoch 52/100
# 235/235 - 2s - loss: 0.2799 - sparse_categorical_accuracy: 0.9011 - val_loss: 0.3549 - val_sparse_categorical_accuracy: 0.8722 - 2s/epoch - 7ms/step
# Epoch 53/100
# 235/235 - 2s - loss: 0.2783 - sparse_categorical_accuracy: 0.9013 - val_loss: 0.3569 - val_sparse_categorical_accuracy: 0.8730 - 2s/epoch - 7ms/step
# Epoch 54/100
# 235/235 - 2s - loss: 0.2765 - sparse_categorical_accuracy: 0.9022 - val_loss: 0.3517 - val_sparse_categorical_accuracy: 0.8745 - 2s/epoch - 7ms/step
# Epoch 55/100
# 235/235 - 2s - loss: 0.2751 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.3518 - val_sparse_categorical_accuracy: 0.8731 - 2s/epoch - 7ms/step
# Epoch 56/100
# 235/235 - 2s - loss: 0.2739 - sparse_categorical_accuracy: 0.9029 - val_loss: 0.3523 - val_sparse_categorical_accuracy: 0.8742 - 2s/epoch - 7ms/step
# Epoch 57/100
# 235/235 - 2s - loss: 0.2724 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.3512 - val_sparse_categorical_accuracy: 0.8731 - 2s/epoch - 7ms/step
# Epoch 58/100
# 235/235 - 2s - loss: 0.2705 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3534 - val_sparse_categorical_accuracy: 0.8729 - 2s/epoch - 7ms/step
# Epoch 59/100
# 235/235 - 2s - loss: 0.2696 - sparse_categorical_accuracy: 0.9044 - val_loss: 0.3560 - val_sparse_categorical_accuracy: 0.8738 - 2s/epoch - 7ms/step
# Epoch 60/100
# 235/235 - 2s - loss: 0.2682 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.3478 - val_sparse_categorical_accuracy: 0.8757 - 2s/epoch - 7ms/step
# Epoch 61/100
# 235/235 - 2s - loss: 0.2668 - sparse_categorical_accuracy: 0.9056 - val_loss: 0.3508 - val_sparse_categorical_accuracy: 0.8748 - 2s/epoch - 7ms/step
# Epoch 62/100
# 235/235 - 2s - loss: 0.2657 - sparse_categorical_accuracy: 0.9057 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8755 - 2s/epoch - 7ms/step
# Epoch 63/100
# 235/235 - 2s - loss: 0.2642 - sparse_categorical_accuracy: 0.9067 - val_loss: 0.3467 - val_sparse_categorical_accuracy: 0.8761 - 2s/epoch - 7ms/step
# Epoch 64/100
# 235/235 - 2s - loss: 0.2633 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.3484 - val_sparse_categorical_accuracy: 0.8735 - 2s/epoch - 7ms/step
# Epoch 65/100
# 235/235 - 2s - loss: 0.2616 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.8739 - 2s/epoch - 7ms/step
# Epoch 66/100
# 235/235 - 2s - loss: 0.2604 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8773 - 2s/epoch - 7ms/step
# Epoch 67/100
# 235/235 - 2s - loss: 0.2595 - sparse_categorical_accuracy: 0.9085 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.8781 - 2s/epoch - 7ms/step
# Epoch 68/100
# 235/235 - 2s - loss: 0.2580 - sparse_categorical_accuracy: 0.9081 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.8783 - 2s/epoch - 7ms/step
# Epoch 69/100
# 235/235 - 2s - loss: 0.2566 - sparse_categorical_accuracy: 0.9097 - val_loss: 0.3431 - val_sparse_categorical_accuracy: 0.8763 - 2s/epoch - 7ms/step
# Epoch 70/100
# 235/235 - 2s - loss: 0.2556 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.3424 - val_sparse_categorical_accuracy: 0.8806 - 2s/epoch - 7ms/step
# Epoch 71/100
# 235/235 - 2s - loss: 0.2541 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.3433 - val_sparse_categorical_accuracy: 0.8777 - 2s/epoch - 7ms/step
# Epoch 72/100
# 235/235 - 2s - loss: 0.2531 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8798 - 2s/epoch - 7ms/step
# Epoch 73/100
# 235/235 - 2s - loss: 0.2522 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.3414 - val_sparse_categorical_accuracy: 0.8760 - 2s/epoch - 7ms/step
# Epoch 74/100
# 235/235 - 2s - loss: 0.2508 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.3431 - val_sparse_categorical_accuracy: 0.8789 - 2s/epoch - 7ms/step
# Epoch 75/100
# 235/235 - 2s - loss: 0.2498 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8781 - 2s/epoch - 7ms/step
# Epoch 76/100
# 235/235 - 2s - loss: 0.2486 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.3473 - val_sparse_categorical_accuracy: 0.8754 - 2s/epoch - 7ms/step
# Epoch 77/100
# 235/235 - 2s - loss: 0.2476 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.3375 - val_sparse_categorical_accuracy: 0.8807 - 2s/epoch - 7ms/step
# Epoch 78/100
# 235/235 - 2s - loss: 0.2462 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.3393 - val_sparse_categorical_accuracy: 0.8778 - 2s/epoch - 7ms/step
# Epoch 79/100
# 235/235 - 2s - loss: 0.2452 - sparse_categorical_accuracy: 0.9138 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8790 - 2s/epoch - 7ms/step
# Epoch 80/100
# 235/235 - 2s - loss: 0.2438 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.3383 - val_sparse_categorical_accuracy: 0.8793 - 2s/epoch - 7ms/step
# Epoch 81/100
# 235/235 - 2s - loss: 0.2430 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8815 - 2s/epoch - 7ms/step
# Epoch 82/100
# 235/235 - 2s - loss: 0.2420 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8761 - 2s/epoch - 7ms/step
# Epoch 83/100
# 235/235 - 2s - loss: 0.2409 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.3343 - val_sparse_categorical_accuracy: 0.8821 - 2s/epoch - 7ms/step
# Epoch 84/100
# 235/235 - 2s - loss: 0.2396 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8822 - 2s/epoch - 7ms/step
# Epoch 85/100
# 235/235 - 2s - loss: 0.2388 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.3352 - val_sparse_categorical_accuracy: 0.8803 - 2s/epoch - 7ms/step
# Epoch 86/100
# 235/235 - 2s - loss: 0.2376 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8785 - 2s/epoch - 7ms/step
# Epoch 87/100
# 235/235 - 2s - loss: 0.2367 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.3334 - val_sparse_categorical_accuracy: 0.8826 - 2s/epoch - 7ms/step
# Epoch 88/100
# 235/235 - 2s - loss: 0.2354 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.3330 - val_sparse_categorical_accuracy: 0.8843 - 2s/epoch - 7ms/step
# Epoch 89/100
# 235/235 - 2s - loss: 0.2346 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8813 - 2s/epoch - 7ms/step
# Epoch 90/100
# 235/235 - 2s - loss: 0.2333 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3327 - val_sparse_categorical_accuracy: 0.8839 - 2s/epoch - 7ms/step
# Epoch 91/100
# 235/235 - 2s - loss: 0.2324 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8774 - 2s/epoch - 7ms/step
# Epoch 92/100
# 235/235 - 2s - loss: 0.2313 - sparse_categorical_accuracy: 0.9197 - val_loss: 0.3339 - val_sparse_categorical_accuracy: 0.8811 - 2s/epoch - 7ms/step
# Epoch 93/100
# 235/235 - 2s - loss: 0.2306 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.3365 - val_sparse_categorical_accuracy: 0.8818 - 2s/epoch - 7ms/step
# Epoch 94/100
# 235/235 - 2s - loss: 0.2295 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8813 - 2s/epoch - 8ms/step
# Epoch 95/100
# 235/235 - 2s - loss: 0.2284 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.3327 - val_sparse_categorical_accuracy: 0.8827 - 2s/epoch - 8ms/step
# Epoch 96/100
# 235/235 - 2s - loss: 0.2276 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.3334 - val_sparse_categorical_accuracy: 0.8829 - 2s/epoch - 8ms/step
# Epoch 97/100
# 235/235 - 2s - loss: 0.2265 - sparse_categorical_accuracy: 0.9210 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8842 - 2s/epoch - 8ms/step
# Epoch 98/100
# 235/235 - 2s - loss: 0.2258 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.3305 - val_sparse_categorical_accuracy: 0.8837 - 2s/epoch - 8ms/step
# Epoch 99/100
# 235/235 - 2s - loss: 0.2250 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.3338 - val_sparse_categorical_accuracy: 0.8808 - 2s/epoch - 7ms/step
# Epoch 100/100
# 235/235 - 2s - loss: 0.2238 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.8849 - 2s/epoch - 7ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
