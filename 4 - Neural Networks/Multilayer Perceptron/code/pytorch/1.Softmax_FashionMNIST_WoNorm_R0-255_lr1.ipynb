# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### Data

# %%
# Load CFashionMNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0,), (1.0/255.0,))])

trainset = torchvision.datasets.FashionMNIST(root='data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1024, num_workers=10, shuffle=True)

testset = torchvision.datasets.FashionMNIST(root='data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=1024, num_workers=10, shuffle=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to display the images
def imshow(img):
    img = img / 255.0
    np_img = img.numpy()
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()

for i, (images, labels) in enumerate(trainloader, 0):
    # Plot some images
    imshow(torchvision.utils.make_grid(images[:8]))  # Display 8 images from the batch
    break

# %% [markdown]
# #### Model

# %%
model = nn.Sequential(
    nn.Flatten(), nn.Linear(784, 10)
)
model = model.to(device)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=10, bias=True)
# )

# %%
# Generating a random tensor
input_tensor = torch.rand(5, 28, 28).to(device)

# Feeding the tensor into the model
output = model(input_tensor)
print(output.shape)
# Out:
# torch.Size([5, 10])

# %% [markdown]
# #### Loss, Optimizer, and Evaluation Function

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
test_loss, test_accuracy = evaluate(model, testloader, criterion)
print(f'test_loss: {test_loss}')
print(f'test_accuracy: {test_accuracy}')
# Out:
# test_loss: 124.80524368286133
# test_accuracy: 12.92

# %% [markdown]
# #### Train

# %%
# some parameter
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
max_epoch = 100

# %%
# train
for epoch in range(max_epoch):
    running_loss = 0.0
    running_correct = 0   # to track number of correct predictions
    total = 0             # to track total number of samples

    for i, (inputs, labels) in enumerate(trainloader, 0):
        # Move inputs and labels to the device
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        # Determine class predictions and track accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()        

    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    test_loss, test_accuracy = evaluate(model, testloader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [1/100], Loss: 4583.8582, Accuracy: 56.28%, Test Loss: 1031.3852, Test Accuracy: 72.75%
# Epoch [2/100], Loss: 1630.1981, Accuracy: 71.91%, Test Loss: 868.3113, Test Accuracy: 73.66%
# Epoch [3/100], Loss: 1508.0356, Accuracy: 72.46%, Test Loss: 2093.6885, Test Accuracy: 70.98%
# Epoch [4/100], Loss: 1341.1388, Accuracy: 74.27%, Test Loss: 652.3525, Test Accuracy: 77.83%
# Epoch [5/100], Loss: 1249.8842, Accuracy: 74.63%, Test Loss: 1263.6461, Test Accuracy: 70.06%
# Epoch [6/100], Loss: 1174.7292, Accuracy: 75.33%, Test Loss: 1376.4801, Test Accuracy: 77.67%
# Epoch [7/100], Loss: 1133.5124, Accuracy: 75.45%, Test Loss: 1001.4365, Test Accuracy: 78.48%
# Epoch [81/100], Loss: 817.5179, Accuracy: 80.08%, Test Loss: 1671.8605, Test Accuracy: 71.38%
# Epoch [82/100], Loss: 860.0776, Accuracy: 79.75%, Test Loss: 1259.3196, Test Accuracy: 75.97%
# Epoch [83/100], Loss: 820.0404, Accuracy: 79.79%, Test Loss: 1157.9383, Test Accuracy: 71.15%
# Epoch [84/100], Loss: 789.2837, Accuracy: 79.62%, Test Loss: 911.2811, Test Accuracy: 80.80%
# Epoch [85/100], Loss: 834.0963, Accuracy: 80.05%, Test Loss: 727.1940, Test Accuracy: 79.86%
# Epoch [86/100], Loss: 877.8880, Accuracy: 79.10%, Test Loss: 648.5544, Test Accuracy: 75.66%
# Epoch [87/100], Loss: 807.5328, Accuracy: 80.04%, Test Loss: 1533.2133, Test Accuracy: 75.35%
# Epoch [88/100], Loss: 856.8846, Accuracy: 79.82%, Test Loss: 777.3765, Test Accuracy: 74.47%
# Epoch [89/100], Loss: 790.5070, Accuracy: 80.16%, Test Loss: 1821.9067, Test Accuracy: 75.03%
# Epoch [90/100], Loss: 811.6672, Accuracy: 79.49%, Test Loss: 1823.7202, Test Accuracy: 78.51%
# Epoch [91/100], Loss: 852.0345, Accuracy: 79.96%, Test Loss: 520.3397, Test Accuracy: 80.39%
# Epoch [92/100], Loss: 818.7470, Accuracy: 80.03%, Test Loss: 1482.2127, Test Accuracy: 73.93%
# Epoch [93/100], Loss: 851.3929, Accuracy: 79.56%, Test Loss: 924.2764, Test Accuracy: 75.64%
# Epoch [94/100], Loss: 857.3909, Accuracy: 79.36%, Test Loss: 622.9635, Test Accuracy: 76.22%
# Epoch [95/100], Loss: 919.3788, Accuracy: 78.86%, Test Loss: 975.4609, Test Accuracy: 76.91%
# Epoch [96/100], Loss: 766.9437, Accuracy: 80.67%, Test Loss: 757.3246, Test Accuracy: 78.69%
# Epoch [97/100], Loss: 810.3582, Accuracy: 79.62%, Test Loss: 999.2669, Test Accuracy: 72.92%
# Epoch [98/100], Loss: 903.2818, Accuracy: 78.75%, Test Loss: 931.9027, Test Accuracy: 80.56%
# Epoch [99/100], Loss: 792.0859, Accuracy: 80.35%, Test Loss: 1232.0540, Test Accuracy: 76.29%
# Epoch [100/100], Loss: 833.7124, Accuracy: 79.94%, Test Loss: 899.0000, Test Accuracy: 80.37%

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()
