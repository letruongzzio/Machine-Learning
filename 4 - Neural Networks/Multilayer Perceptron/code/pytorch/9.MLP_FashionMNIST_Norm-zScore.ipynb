# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### Data

# %%
# Load dataset with only the ToTensor transform to compute mean and std
compute_transform = transforms.Compose([transforms.ToTensor()])
dataset = torchvision.datasets.FashionMNIST(root='data', train=True, transform=compute_transform, download=True)
loader = torch.utils.data.DataLoader(dataset, batch_size=1024, shuffle=False, num_workers=10)

mean = 0.0
for images, _ in loader:
    batch_samples = images.size(0)  # Batch size
    images = images.view(batch_samples, images.size(1), -1)
    mean += images.mean(2).sum(0)
mean = mean / len(loader.dataset)

variance = 0.0
for images, _ in loader:
    batch_samples = images.size(0)
    images = images.view(batch_samples, images.size(1), -1)
    variance += ((images - mean.unsqueeze(1))**2).sum([0,2])
std = torch.sqrt(variance / (len(loader.dataset)*28*28))

print(mean, std)
# Out:
# tensor([0.2860]) tensor([0.3530])

# %%
# Load CFashionMNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((mean,), (std,))])

trainset = torchvision.datasets.FashionMNIST(root='data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1024, num_workers=10, shuffle=True)

testset = torchvision.datasets.FashionMNIST(root='data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=1024, num_workers=10, shuffle=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to display the images
def imshow(img):
    img = img*std + mean
    np_img = img.numpy()
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()

for i, (images, labels) in enumerate(trainloader, 0):
    # Plot some images
    imshow(torchvision.utils.make_grid(images[:8]))  # Display 8 images from the batch
    break

# %% [markdown]
# #### Model

# %%
model = nn.Sequential(
    nn.Flatten(), 
    nn.Linear(784, 256),
    nn.ReLU(),
    nn.Linear(256, 10)
)
model = model.to(device)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=256, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
# Generating a random tensor
input_tensor = torch.rand(5, 28, 28).to(device)

# Feeding the tensor into the model
output = model(input_tensor)
print(output.shape)
# Out:
# torch.Size([5, 10])

# %% [markdown]
# #### Loss, Optimizer, and Evaluation Function

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
test_loss, test_accuracy = evaluate(model, testloader, criterion)
print(f'test_loss: {test_loss}')
print(f'test_accuracy: {test_accuracy}')
# Out:
# test_loss: 2.376007056236267
# test_accuracy: 9.3

# %% [markdown]
# #### Train

# %%
# some parameter
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
max_epoch = 200

# %%
# train
for epoch in range(max_epoch):
    running_loss = 0.0
    running_correct = 0   # to track number of correct predictions
    total = 0             # to track total number of samples

    for i, (inputs, labels) in enumerate(trainloader, 0):
        # Move inputs and labels to the device
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        # Determine class predictions and track accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()        

    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    test_loss, test_accuracy = evaluate(model, testloader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [1/200], Loss: 1.6916, Accuracy: 50.67%, Test Loss: 1.2509, Test Accuracy: 66.39%
# Epoch [2/200], Loss: 1.0630, Accuracy: 69.60%, Test Loss: 0.9384, Test Accuracy: 71.11%
# Epoch [3/200], Loss: 0.8582, Accuracy: 72.84%, Test Loss: 0.8089, Test Accuracy: 72.99%
# Epoch [4/200], Loss: 0.7597, Accuracy: 74.76%, Test Loss: 0.7369, Test Accuracy: 74.90%
# Epoch [5/200], Loss: 0.7005, Accuracy: 76.24%, Test Loss: 0.6905, Test Accuracy: 76.31%
# Epoch [6/200], Loss: 0.6596, Accuracy: 77.44%, Test Loss: 0.6575, Test Accuracy: 77.16%
# Epoch [7/200], Loss: 0.6290, Accuracy: 78.36%, Test Loss: 0.6327, Test Accuracy: 77.86%
# Epoch [8/200], Loss: 0.6058, Accuracy: 79.19%, Test Loss: 0.6115, Test Accuracy: 78.68%
# Epoch [9/200], Loss: 0.5863, Accuracy: 79.78%, Test Loss: 0.5953, Test Accuracy: 79.14%
# Epoch [10/200], Loss: 0.5697, Accuracy: 80.32%, Test Loss: 0.5813, Test Accuracy: 79.61%
# Epoch [11/200], Loss: 0.5567, Accuracy: 80.77%, Test Loss: 0.5690, Test Accuracy: 80.03%
# Epoch [12/200], Loss: 0.5446, Accuracy: 81.13%, Test Loss: 0.5589, Test Accuracy: 80.41%
# Epoch [13/200], Loss: 0.5343, Accuracy: 81.50%, Test Loss: 0.5503, Test Accuracy: 80.60%
# Epoch [14/200], Loss: 0.5255, Accuracy: 81.78%, Test Loss: 0.5426, Test Accuracy: 80.84%
# Epoch [15/200], Loss: 0.5170, Accuracy: 82.04%, Test Loss: 0.5352, Test Accuracy: 80.99%
# Epoch [16/200], Loss: 0.5097, Accuracy: 82.27%, Test Loss: 0.5292, Test Accuracy: 81.21%
# Epoch [17/200], Loss: 0.5032, Accuracy: 82.47%, Test Loss: 0.5229, Test Accuracy: 81.41%
# Epoch [18/200], Loss: 0.4969, Accuracy: 82.70%, Test Loss: 0.5178, Test Accuracy: 81.59%
# Epoch [19/200], Loss: 0.4915, Accuracy: 82.84%, Test Loss: 0.5131, Test Accuracy: 81.67%
# Epoch [20/200], Loss: 0.4862, Accuracy: 83.05%, Test Loss: 0.5086, Test Accuracy: 81.86%
# Epoch [21/200], Loss: 0.4813, Accuracy: 83.21%, Test Loss: 0.5046, Test Accuracy: 81.91%
# Epoch [180/200], Loss: 0.3129, Accuracy: 88.89%, Test Loss: 0.3691, Test Accuracy: 86.82%
# Epoch [181/200], Loss: 0.3125, Accuracy: 88.95%, Test Loss: 0.3698, Test Accuracy: 87.01%
# Epoch [182/200], Loss: 0.3122, Accuracy: 88.91%, Test Loss: 0.3685, Test Accuracy: 86.99%
# Epoch [183/200], Loss: 0.3113, Accuracy: 88.97%, Test Loss: 0.3684, Test Accuracy: 86.94%
# Epoch [184/200], Loss: 0.3110, Accuracy: 88.94%, Test Loss: 0.3675, Test Accuracy: 87.02%
# Epoch [185/200], Loss: 0.3108, Accuracy: 89.03%, Test Loss: 0.3674, Test Accuracy: 87.00%
# Epoch [186/200], Loss: 0.3102, Accuracy: 89.03%, Test Loss: 0.3670, Test Accuracy: 87.07%
# Epoch [187/200], Loss: 0.3098, Accuracy: 89.08%, Test Loss: 0.3670, Test Accuracy: 86.86%
# Epoch [188/200], Loss: 0.3093, Accuracy: 89.03%, Test Loss: 0.3664, Test Accuracy: 87.00%
# Epoch [189/200], Loss: 0.3091, Accuracy: 89.07%, Test Loss: 0.3674, Test Accuracy: 86.89%
# Epoch [190/200], Loss: 0.3083, Accuracy: 89.09%, Test Loss: 0.3666, Test Accuracy: 87.04%
# Epoch [191/200], Loss: 0.3081, Accuracy: 89.11%, Test Loss: 0.3665, Test Accuracy: 86.98%
# Epoch [192/200], Loss: 0.3079, Accuracy: 89.09%, Test Loss: 0.3679, Test Accuracy: 87.01%
# Epoch [193/200], Loss: 0.3072, Accuracy: 89.17%, Test Loss: 0.3648, Test Accuracy: 87.10%
# Epoch [194/200], Loss: 0.3070, Accuracy: 89.17%, Test Loss: 0.3654, Test Accuracy: 86.96%
# Epoch [195/200], Loss: 0.3064, Accuracy: 89.15%, Test Loss: 0.3661, Test Accuracy: 87.06%
# Epoch [196/200], Loss: 0.3066, Accuracy: 89.16%, Test Loss: 0.3648, Test Accuracy: 86.99%
# Epoch [197/200], Loss: 0.3059, Accuracy: 89.19%, Test Loss: 0.3642, Test Accuracy: 87.10%
# Epoch [198/200], Loss: 0.3048, Accuracy: 89.21%, Test Loss: 0.3640, Test Accuracy: 86.98%
# Epoch [199/200], Loss: 0.3046, Accuracy: 89.22%, Test Loss: 0.3639, Test Accuracy: 87.14%
# Epoch [200/200], Loss: 0.3043, Accuracy: 89.25%, Test Loss: 0.3631, Test Accuracy: 87.10%

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()
