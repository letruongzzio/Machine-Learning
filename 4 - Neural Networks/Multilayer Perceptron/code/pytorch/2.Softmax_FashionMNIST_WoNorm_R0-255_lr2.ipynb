# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### Data

# %%
# Load CFashionMNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0,), (1.0/255.0,))])

trainset = torchvision.datasets.FashionMNIST(root='data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1024, num_workers=10, shuffle=True)

testset = torchvision.datasets.FashionMNIST(root='data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=1024, num_workers=10, shuffle=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to display the images
def imshow(img):
    img = img / 255.0
    np_img = img.numpy()
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()

for i, (images, labels) in enumerate(trainloader, 0):
    # Plot some images
    imshow(torchvision.utils.make_grid(images[:8]))  # Display 8 images from the batch
    break

# %% [markdown]
# #### Model

# %%
model = nn.Sequential(
    nn.Flatten(), nn.Linear(784, 10)
)
model = model.to(device)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=10, bias=True)
# )

# %%
# Generating a random tensor
input_tensor = torch.rand(5, 28, 28).to(device)

# Feeding the tensor into the model
output = model(input_tensor)
print(output.shape)
# Out:
# torch.Size([5, 10])

# %% [markdown]
# #### Loss, Optimizer, and Evaluation Function

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.00001)

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
test_loss, test_accuracy = evaluate(model, testloader, criterion)
print(f'test_loss: {test_loss}')
print(f'test_accuracy: {test_accuracy}')
# Out:
# test_loss: 132.6778366088867
# test_accuracy: 16.04

# %% [markdown]
# #### Train

# %%
# some parameter
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
max_epoch = 100

# %%
# train
for epoch in range(max_epoch):
    running_loss = 0.0
    running_correct = 0   # to track number of correct predictions
    total = 0             # to track total number of samples

    for i, (inputs, labels) in enumerate(trainloader, 0):
        # Move inputs and labels to the device
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        # Determine class predictions and track accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()        

    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    test_loss, test_accuracy = evaluate(model, testloader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [1/100], Loss: 32.8239, Accuracy: 29.39%, Test Loss: 16.7562, Test Accuracy: 44.88%
# Epoch [2/100], Loss: 14.0186, Accuracy: 51.24%, Test Loss: 12.2603, Test Accuracy: 55.18%
# Epoch [3/100], Loss: 11.1198, Accuracy: 58.00%, Test Loss: 10.5141, Test Accuracy: 59.42%
# Epoch [4/100], Loss: 9.7300, Accuracy: 61.36%, Test Loss: 9.5287, Test Accuracy: 61.40%
# Epoch [5/100], Loss: 8.8593, Accuracy: 63.59%, Test Loss: 8.8143, Test Accuracy: 63.95%
# Epoch [6/100], Loss: 8.2486, Accuracy: 65.39%, Test Loss: 8.3148, Test Accuracy: 65.20%
# Epoch [7/100], Loss: 7.7928, Accuracy: 66.62%, Test Loss: 7.9514, Test Accuracy: 66.33%
# Epoch [81/100], Loss: 3.1319, Accuracy: 77.69%, Test Loss: 3.5555, Test Accuracy: 75.85%
# Epoch [82/100], Loss: 3.1143, Accuracy: 77.69%, Test Loss: 3.5265, Test Accuracy: 76.17%
# Epoch [83/100], Loss: 3.0871, Accuracy: 77.86%, Test Loss: 3.5281, Test Accuracy: 75.94%
# Epoch [84/100], Loss: 3.0798, Accuracy: 77.83%, Test Loss: 3.5098, Test Accuracy: 76.43%
# Epoch [85/100], Loss: 3.0558, Accuracy: 77.86%, Test Loss: 3.5202, Test Accuracy: 76.58%
# Epoch [86/100], Loss: 3.0483, Accuracy: 77.81%, Test Loss: 3.4577, Test Accuracy: 76.54%
# Epoch [87/100], Loss: 3.0326, Accuracy: 77.88%, Test Loss: 3.4633, Test Accuracy: 76.17%
# Epoch [88/100], Loss: 3.0246, Accuracy: 77.86%, Test Loss: 3.4519, Test Accuracy: 76.19%
# Epoch [89/100], Loss: 2.9975, Accuracy: 77.97%, Test Loss: 3.4508, Test Accuracy: 76.64%
# Epoch [90/100], Loss: 2.9910, Accuracy: 77.94%, Test Loss: 3.4036, Test Accuracy: 76.54%
# Epoch [91/100], Loss: 2.9756, Accuracy: 78.08%, Test Loss: 3.3920, Test Accuracy: 76.87%
# Epoch [92/100], Loss: 2.9550, Accuracy: 78.05%, Test Loss: 3.3913, Test Accuracy: 76.48%
# Epoch [93/100], Loss: 2.9436, Accuracy: 78.04%, Test Loss: 3.3651, Test Accuracy: 76.36%
# Epoch [94/100], Loss: 2.9266, Accuracy: 78.14%, Test Loss: 3.3618, Test Accuracy: 76.24%
# Epoch [95/100], Loss: 2.9178, Accuracy: 78.08%, Test Loss: 3.3444, Test Accuracy: 76.49%
# Epoch [96/100], Loss: 2.9007, Accuracy: 78.11%, Test Loss: 3.3549, Test Accuracy: 76.97%
# Epoch [97/100], Loss: 2.8896, Accuracy: 78.18%, Test Loss: 3.3467, Test Accuracy: 76.38%
# Epoch [98/100], Loss: 2.8744, Accuracy: 78.20%, Test Loss: 3.3038, Test Accuracy: 76.98%
# Epoch [99/100], Loss: 2.8561, Accuracy: 78.25%, Test Loss: 3.3132, Test Accuracy: 76.23%
# Epoch [100/100], Loss: 2.8474, Accuracy: 78.28%, Test Loss: 3.3013, Test Accuracy: 76.87%

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()
